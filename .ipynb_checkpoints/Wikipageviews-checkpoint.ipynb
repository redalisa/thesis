# %% [markdown]
# ## Wikipedia Page View Retrieval and Digital Data Comparisons

# %% [markdown]
# ### Pageview Retrieval

# %%
import pandas as pd
import json
from ast import literal_eval
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import json
import base64
import requests
import bs4
from bs4 import BeautifulSoup
import re

from requests.structures import CaseInsensitiveDict
#from ratelimit import limits, RateLimitException, sleep_and_retry
# pip install ratelimit

# %%
# Read in speciesinfo CSV
species = pd.read_csv("csv/speciesinfo.csv", sep = ";")
species.drop_duplicates(inplace = True)
species = species.reset_index(drop = True)
len(species)
# Out:
# 561

# %% [markdown]
# ## Wikipedia API

# %%
# pip3 install wikipedia-api
import wikipediaapi
# only english language pages
api = wikipediaapi.Wikipedia('en')

wikiurls = []
# loop through the unique species names
for name in species['scientific_name'].unique():
    # Spaces to be replaced with underscore for Wiki's API
    name = name.replace(" ", "_")
    # retrieve each species' page, will redirect when called with scientifc name
    p = api.page(name)
    try:
        # Fullurl will contain the title of the species' wiki article
        data = {'url': p.fullurl, 'scientific_name': name}
        wikiurls.append(data)
    # species did not return with a valid url, no page exists for the species
    except KeyError:
        pass
    
# investigate how many species left   
len(wikiurls)

# %%
def WikiPageView(title):
    """
    Function to call Wikipedia's Pageview API
    
    Parameters: string
    
    """
    
    # Calling monthly page views of each species from 2015-2020
    address = "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia.org/all-access/user/" + title + "/monthly/2015010100/2020123100"

    headers = CaseInsensitiveDict()
    headers["Accept"] = "application/json"
    # Personal username for identification for the Wikipedia API
    headers = {'User-Agent': 'reddalisa/3.10.6 (alisa.redding@helsinki.fi)'}
    
    resp = requests.get(address, headers=headers)
    details = resp.json()
    
    return details 
      
    
# Create an empty list to store the pageviews results into
newframe = []  

# loop over the urls to extract the titles of the wikipages
for n in range(len(wikiurls)):
    name = wikiurls[n]['url'].removeprefix("https://en.wikipedia.org/wiki/")
    # using the extracted name, run through the function
    result = WikiPageView(name)
    sci_name = wikiurls[n]['scientific_name']
    
    try:
        # loop over the json results to store the relevant information 
        for n in range(len(result['items'])):
            title = result['items'][n]['article']
            date = result['items'][n]['timestamp']
            # Remove 00 at end of date string that is marking the hour
            date = date[:-2]
            view = result['items'][n]['views']
            
            # create a dictionary object 
            data = {'title': title, 'date': date, 'views': view, 'scientific_name' : sci_name}
            newframe.append(data)
    # Some pages have not been incorporated into the PageViews API yet, they will be passed
    except KeyError:
        pass

# %%
# Create a dataframe from the list
#wikipage = pd.DataFrame(newframe)
#wikipage["datetime"] = wikipage["date"].apply(pd.to_datetime)
wikipage = wikipage.drop(columns = 'date')
wikipage['title'] = wikipage["title"].apply(lambda x: x.replace("_", " "))
wikipage['scientific_name'] = wikipage["scientific_name"].apply(lambda x: x.replace("_", " "))
#len(wikipage['name'].unique())

# %%
# view highest view count
wikipage.sort_values(by="views", ascending = False)
# Out:
#                         title   views       scientific_name   datetime
# 2762                    Tiger  694465       Panthera tigris 2020-03-01
# 9262                Red panda  652891       Ailurus fulgens 2017-05-01
# 614                      Lion  574872          Panthera leo 2017-03-01
# 650                      Lion  574083          Panthera leo 2020-03-01
# 2763                    Tiger  540666       Panthera tigris 2020-04-01
# ...                       ...     ...                   ...        ...
# 34056  Milne-Edwards's sifaka       0  Propithecus edwardsi 2018-07-01
# 34057  Milne-Edwards's sifaka       0  Propithecus edwardsi 2018-08-01
# 34058  Milne-Edwards's sifaka       0  Propithecus edwardsi 2018-09-01
# 34059  Milne-Edwards's sifaka       0  Propithecus edwardsi 2018-10-01
# 34043  Milne-Edwards's sifaka       0  Propithecus edwardsi 2017-05-01
#
# [35868 rows x 4 columns]

# %%
speciesinfo = pd.merge(species, wikipage.groupby('scientific_name')['views'].sum().reset_index(), on='scientific_name', how = 'inner').drop_duplicates()

# %%
speciesinfo.to_csv("csv/fullspeciesinfo.csv", sep = ";", index = False)

# %%
wikipage.to_csv("csv/wikipageviews.csv", sep = ";", index = False)

# %% [markdown]
# ## Temporal Visualization & WordCloud

# %% [markdown]
# ### Articles: Facebook shares

# %%
# Read in the updated CSVs 

articles = pd.read_csv("updated_articles_w_engangement.csv", sep = ";")
#undoc = pd.read_csv("csv/undoc_species_articles.csv", sep = ";")
speciesinfo = pd.read_csv("csv/fullspeciesinfo.csv", sep = ";")
wiki = pd.read_csv("csv/wikipageviews.csv", sep = ";")

# %%
speciesinfo = pd.merge(speciesinfo, wiki[['scientific_name', 'title']], on='scientific_name', how='right').drop_duplicates().reset_index(drop=True)

# %%
# Simplify the IUCN categories
articles["iucn_status"].replace({"Least Concern": "LC", "Lower Risk/least concern": "LC", "Lower Risk/conservation dependent": "LC",
                                "Vulnerable" : "VU", "Near Threatened" : "NT", "Critically Endangered" : "CR",
                          "Extinct in the Wild" : "EW", "Endangered" : "EN", "Data Deficient" : "DD", 
                          "Extinct" : "EX"}, inplace=True)

# %%
articles = pd.merge(articles, speciesinfo, on = "scientific_name", how = "left")

# %%
# Only keep articles with shares
shared = articles.loc[articles['shares'] > 0].reset_index(drop = True)

# Define a binary classification in a new column for popularity
shared['Popular'] = 0

# Loop over the values in the shares column and if above the median classify as popular
for x in shared["shares"]:
    if x > shared["shares"].mean():
        shared.loc[shared['shares'] == x, 'Popular'] = 1

# %%
from PIL import Image 

pangolin_mask = np.array(Image.open("figures/pangolin_silhouette.png"))

def transform_format(val):
    if val == 0:
        return 255
    else:
        return val
    
# Transform your mask into a new one that will work with the function:
transformed_mask = np.ndarray((pangolin_mask.shape[0],pangolin_mask.shape[1]), np.int32)

for i in range(len(pangolin_mask)):
    transformed_mask[i] = list(map(transform_format, pangolin_mask[i]))

# %%
from wordcloud import WordCloud #pip install wordcloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS

# Articles with greater than the avergae amount of shares in the dataset
popular = shared.loc[shared['Popular'] == 1]
# Articles with greater than 10,000 shares on Facebook (23 articles)
above10thou = articles.loc[articles['shares'] > 10000].reset_index(drop = True)

# Change to choose a certain IUCN status to display
critical = articles.loc[articles['iucn_status'] == "CR"].reset_index(drop = True)
# PLant kingdom articles
plants = articles.loc[articles['Kingdom'] == "Plantae"].reset_index(drop = True)
# Animal kingdom articles
animals = articles.loc[articles['Kingdom'] == "Animalia"].reset_index(drop = True)
# Bird articles
birds = articles.loc[articles['Class'] == "Aves"].reset_index(drop = True)
# Mammal articles
mammals = articles.loc[articles['Class'] == "Mammalia"].reset_index(drop = True)
# Reptile articles
reptiles = articles.loc[articles['Class'] == "Reptilia"].reset_index(drop = True)
amphibia = articles.loc[articles['Class'] == "Amphibia"].reset_index(drop = True)
insects = articles.loc[articles['Class'] == "Insecta"].reset_index(drop = True)
pangolins = articles.loc[articles['Order'] == "Pholidota"].reset_index(drop = True)
# UNDOC's species to watch for illegal trade
undoc = undoc.dropna(subset = ['title'])

# Change to title or text
text = " ".join(i for i in insects.title)
print ("There are {} words in the combination of all cells in column title.".format(len(text))) 

stopwords = set(STOPWORDS)
stopwords.update(["Animal", "animal", "Animals", "species", "s"])
wordcloud = WordCloud(stopwords=stopwords, 
                      background_color="white", 
                      font_path='fonts/Poppins-Medium.ttf',
                      width=800, 
                      height=400, 
                      #mask=transformed_mask, 
                      #contour_width=1, 
                      #contour_color='green'
                      ).generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis("off")
plt.show()

wordcloud.to_file("figures/wordcloud_insects.png")
# Out:
# There are 1117 words in the combination of all cells in column title.

# %%
articles = articles.drop(columns = ["date_saved", "sharecount_x", "sharecount_y"])
articles['date'] = pd.to_datetime(articles['date'])

# %%
articleshares = articles.groupby([(articles.date.dt.year), (articles.date.dt.month), (articles.scientific_name)])['shares'].sum()\
                .sort_values(ascending=False).rename_axis(["Year", "Month", "scientific_name"]).reset_index()

ar16 = articleshares.loc[articleshares['Year'].isin([2016])]
chosen = ar16.sort_values('shares').drop_duplicates('scientific_name',keep='last').tail(5)
chosen = chosen['scientific_name'].values.tolist()
ar16 = ar16.loc[ar16['scientific_name'].isin(chosen)]

ar17 = articleshares.loc[articleshares['Year'].isin([2017])]
chosen = ar17.sort_values('shares').drop_duplicates('scientific_name',keep='last').tail(5)
chosen = chosen['scientific_name'].values.tolist()
ar17 = ar17.loc[ar17['scientific_name'].isin(chosen)]

ar18 = articleshares.loc[articleshares['Year'].isin([2018])]
chosen = ar18.sort_values('shares').drop_duplicates('scientific_name',keep='last').tail(5)
chosen = chosen['scientific_name'].values.tolist()
ar18 = ar18.loc[ar18['scientific_name'].isin(chosen)]

ar19 = articleshares.loc[articleshares['Year'].isin([2019])]
chosen = ar19.sort_values('shares').drop_duplicates('scientific_name',keep='last').tail(5)
chosen = chosen['scientific_name'].values.tolist()
ar19 = ar19.loc[ar19['scientific_name'].isin(chosen)]

ar20 = articleshares.loc[articleshares['Year'].isin([2020])]
chosen = ar20.sort_values('shares').drop_duplicates('scientific_name',keep='last').tail(5)
chosen = chosen['scientific_name'].values.tolist()
ar20 = ar20.loc[ar20['scientific_name'].isin(chosen)]

# %%
# Replace common name for Crocodylus cataphractus which should be West African slender-snouted crocodile 
# and not the Genus name Mecistops. New scientific name should be updated to Mecistops cataphractus

articles['title_y'] = articles['title_y'].replace('Mecistops', 'West African slender-snouted crocodile')
speciesinfo['title'] = speciesinfo['title'].replace('Mecistops', 'West African slender-snouted crocodile')

# %%
#Isolating top 20 most shared species' articles 

shared = articles.groupby('scientific_name')['shares'].sum().nlargest(20).reset_index()#['scientific_name'].values.tolist()
#articspan = articles.loc[articles['scientific_name'].isin(shared)]
#articspan = articles.loc[articles.date.dt.year > 2015]
#articspan = articspan.reset_index(drop = True)

#shared = shared.drop(columns = ["sharecount"])
shared = pd.merge(shared, speciesinfo, on = "scientific_name", how = "left")
#shared = shared.drop(columns = ["sharecount"])

# %%
# Isolate 15 most shared titles from Facebook
# Drop irrelevant title (identified from a manual inspection) 

titles = articles.groupby(['scientific_name', 'title_y', 'title_x', 'Class_x'])['shares'].sum().nlargest(16).reset_index()
titles = titles.drop(5).reset_index(drop=True)

# %%
titles
# Out:
#             scientific_name                                 title_y  \
# 0    Physeter macrocephalus                             Sperm whale
# 1            Pongo pygmaeus                       Bornean orangutan
# 2        Leopardus pardalis                                  Ocelot
# 3          Struthio camelus                          Common ostrich
# 4   Crocodylus cataphractus  West African slender-snouted crocodile
# 5           Manis tricuspis                           Tree pangolin
# 6         Chelonoidis niger                      Galápagos tortoise
# 7        Leopardus pardalis                                  Ocelot
# 8    Semnopithecus entellus             Northern plains gray langur
# 9         Pelecanus crispus                       Dalmatian pelican
# 10             Panthera leo                                    Lion
# 11      Varanus komodoensis                           Komodo dragon
# 12          Elephas maximus                          Asian elephant
# 13                Pudu puda                           Southern pudu
# 14      Piliocolobus kirkii                    Zanzibar red colobus
#
#                                               title_x   Class_x    shares
# 0   Found, Inside Dead Sperm Whale: 100 Plastic Cu...  Mammalia  259996.0
# 1   Pregnant orang-utan pictured clinging to final...  Mammalia  122918.0
# 2   Rare Footage of Arizona Ocelot Shows What Coul...  Mammalia   58998.0
# 3          Quiz: What animal does each eye belong to?      Aves   51545.0
# 4   Fate of Africa's newest, rarest crocodile tied...  Reptilia   47212.0
# 5   Is This Clothing, Food, or an Endangered Speci...  Mammalia   46432.0
# 6   A Giant Galapagos Tortoise Once Thought Extinc...  Reptilia   32920.0
# 7   Texas Ocelot Den Found for First Time in Two D...  Mammalia   30420.0
# 8   This Roadside Mechanic from Rajasthan Has Resc...  Mammalia   28814.0
# 9   Amazing Winners of the 2019 Bird Photographer ...      Aves   24795.0
# 10  Trump Admin Grants First Lion Trophy Import Pe...  Mammalia   19740.0
# 11  Komodo dragon destroyed BBC camera by trying t...  Reptilia   18542.0
# 12                  Baby elephant born in Pairi Daiza  Mammalia   18120.0
# 13  Meet these 30 obscure animals you probably hav...  Mammalia   17040.0
# 14  The Faces of Extinction: The Species We Lost i...  Mammalia   15417.0

# %%
# Visualization of species with highest share count overall

import seaborn as sns
from matplotlib import rc, font_manager, ticker
from textwrap import wrap


sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(14,12)})

palette = {"Mammalia": "#8dd3c7", "Reptilia": "#bebada", "Aves": "#ffffb3"}
plt.rcParams["axes.grid.axis"] ="y"

ax = sns.barplot(
    x = 'title',
    y = 'shares',
    hue = 'Class',
    data = shared, 
    width = 0.7, palette = palette, dodge = False
)
ax.set_xlabel('Species: Common Name', fontsize=16, family = "Serif")
ax.set_ylabel('Facebook Shares', fontsize=16, family = "Serif")


# Add suptitle above the title
plt.suptitle("Top 20 Species by Facebook Shares\n", fontsize=18, family= 'Serif')
plt.subplots_adjust(top=0.94)

# Add title
#ax.title("Realized by the Python Graph Gallery", color="grey", style='italic')
ax.set_title('The Sum of Facebook Shares of Online News Articles', fontsize = 14, color="grey", style='italic', family = 'Serif')

font = font_manager.FontProperties(family='Serif',
                                  weight='regular',
                                  style='italic', size=14)

#fontProperties = {'family': 'Serif', 'color':  'k', 'weight': 'normal', 'style':'italic', 'size': 12}
 
# Set font for x-axis labels
for label in ax.get_xticklabels():
    label.set_fontproperties(font)

import textwrap
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=85)
  

wrap_labels(ax, 25)   
#ax.tick_params(axis='x', rotation=85, length = 9, labelsize = 14, left = True)
ax.legend(bbox_to_anchor=(0.8, 0.95), loc='upper left', borderaxespad=0, prop=font)
plt.savefig('figures/top_20_species_fb.png', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.font_manager as font_manager
import matplotlib.ticker as ticker

sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(14,12)})
plt.rcParams["axes.grid.axis"] ="y"

plt.rcParams["axes.axisbelow"] = "line"


palette = {"Mammalia": "#8dd3c7", "Reptilia": "#bebada", "Aves": "#ffffb3"}
label_dict = {"Mammalia": "Mammalia", "Reptilia":"Reptilia", "Aves":"Aves"}

# Define fontstyle for legend
label_font = {'family': 'serif',
              'size': 12,
              'weight': 'italic'}


ax = sns.barplot(
    x = 'shares', 
    y = 'title_x',
    hue = 'Class_x',
    data = titles,
    width = 0.7,
    #marker = "o", 
    palette = "Set3",
    dodge = False)


ax.set_ylabel('Facebook Shares', fontsize=12, family = "Serif")
ax.set_xlabel('Articles Titles', fontsize=12, family = "Serif")
#ax.set_yscale('log')

# Add suptitle above the title
plt.suptitle("The 15 Most Shared Titles on Facebook\n", fontsize=16, family = 'Serif')
plt.subplots_adjust(top=0.96)

# Add title
#ax.title("Realized by the Python Graph Gallery", color="grey", style='italic')
#ax.set_title('The Sum of Facebook Shares of Online News Articles', fontsize = 10, color="grey", style='italic', family = 'Serif')

font = font_manager.FontProperties(family='Serif',
                                  weight='regular',
                                  style='italic', size=14)

font_titles = {'family': 'Serif','weight': 'normal','style':'italic','size': 9}

#tick_spacing = 1
#ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax.set_yticklabels(titles['title_x'], horizontalalignment = "left", fontdict = font_titles)
ax.tick_params(axis='y', direction = "in", pad = -15)
#ax.tick_params(axis='x', rotation=85, length = 9, labelsize = 12, left = True)
#plt.rcParams["axes.grid.axis"] ="x"

# Customize the legend
handles, labels = plt.gca().get_legend_handles_labels()
ax.legend(handles, labels, bbox_to_anchor=(0.8, 0.03), loc='lower left', borderaxespad=0, prop=font)
#ax.legend(bbox_to_anchor=(0.8, 0.95), loc='upper left', borderaxespad=0, prop=font)
#ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, prop=font)
plt.savefig('figures/facebook_sharedarticles.png', bbox_inches = 'tight')

# %% [markdown]
# ### Wikipedia Pageviews

# %%
# read in store wiki data
wiki = pd.read_csv("csv/wikipageviews.csv", sep = ";")
# merge with relevant species info
wiki = pd.merge(wiki, species[['scientific_name', 'Kingdom', 'Class', 'Order', 'Family', 'Genus', 'Species']], on = "scientific_name", how='left')
# transform date column into datetime for processing + plotting purposes 
wiki["datetime"] = pd.to_datetime(wiki['datetime'])

# create a grouped by month+year dataframe 
temporal_wiki = wiki.groupby([(wiki.datetime.dt.year), (wiki.datetime.dt.month), (wiki.scientific_name)])['views'].sum()\
                .sort_values(ascending=False).rename_axis(["Year", "Month", "scientific_name"]).reset_index()

# %%
# Finding 5 most popular species of each year and plot their popularity over the year
yr20 = temporal_wiki.loc[temporal_wiki['Year'].isin([2020])]
chosen20 = yr20.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(5)
chosen20 = chosen20['scientific_name'].values.tolist()
yr20 = yr20.loc[yr20['scientific_name'].isin(chosen20)]

yr19 = temporal_wiki.loc[temporal_wiki['Year'].isin([2019])]
chosen19 = yr19.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(5)
chosen19 = chosen19['scientific_name'].values.tolist()
yr19 = yr19.loc[yr19['scientific_name'].isin(chosen19)]

yr18 = temporal_wiki.loc[temporal_wiki['Year'].isin([2018])]
chosen18 = yr18.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(5)
chosen18 = chosen18['scientific_name'].values.tolist()
yr18 = yr18.loc[yr18['scientific_name'].isin(chosen18)]

yr17 = temporal_wiki.loc[temporal_wiki['Year'].isin([2017])]
chosen17 = yr17.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(5)
chosen17 = chosen17['scientific_name'].values.tolist()
yr17 = yr17.loc[yr17['scientific_name'].isin(chosen17)]

yr16 = temporal_wiki.loc[temporal_wiki['Year'].isin([2016])]
chosen16 = yr16.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(5)
chosen16 = chosen16['scientific_name'].values.tolist()
yr16 = yr16.loc[yr16['scientific_name'].isin(chosen16)]

# A list of unique species composed of each years' top 5 species 
#uniques = list(set(chosen20 + chosen19 + chosen18 + chosen17 + chosen16))

# %%
# A list of 10 species with the highest pageview count for one month from the entire 5 year timespan that has been collected (the highest peaks)
peaks = wiki.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(10)['scientific_name'].values.tolist()
# A list of 10 species with the highest overall pageview count from the entire 5 year timespan 
topoverall = wiki.groupby('scientific_name')['views'].sum().nlargest(10).reset_index()['scientific_name'].values.tolist()
# Change to topoverall or peaks to store an excerpt of the dataframe to visualize
topalltime = wiki.loc[wiki['scientific_name'].isin(topoverall)]
alltimepeaks = wiki.loc[wiki['scientific_name'].isin(peaks)]


# Species specific investigations
# Visualizations for articles tagged with Aves 
birds = wiki.loc[wiki['Class'] == "Aves"].reset_index(drop = True)
# A list of 10 birds with highest peaks
birdpeaks = birds.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(10)['scientific_name'].values.tolist()
alltimebirds = birds.loc[birds['scientific_name'].isin(birdpeaks)]

# Visualizations for articles tagged with Mammalia
mammals = wiki.loc[wiki['Class'] == "Mammalia"].reset_index(drop = True)
# A list of 10 birds with highest peaks
mammalpeaks = mammals.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(10)['scientific_name'].values.tolist()
alltimemammals = mammals.loc[mammals['scientific_name'].isin(mammalpeaks)]

# Visualizations for articles tagged with Reptilia
reps = wiki.loc[wiki['Class'] == "Reptilia"].reset_index(drop = True)
# A list of 10 birds with highest peaks
reppeaks = reps.sort_values('views').drop_duplicates('scientific_name',keep='last').tail(10)['scientific_name'].values.tolist()
alltimereps = reps.loc[reps['scientific_name'].isin(reppeaks)]

# %%
# Store to CSV
topalltime.to_csv("csv/wiki-top10alltime.csv", sep = ";", index = False)
alltimepeaks.to_csv("csv/wiki-10alltimepeaks.csv", sep = ";", index = False)

# %%
import seaborn as sns
import matplotlib.font_manager as font_manager
import matplotlib.ticker as ticker
# Import packages
import cmasher as cmr

# Take 5 colors from rainforest in [0.15, 0.85] range in HEX
colors = cmr.take_cmap_colors('tab10', 
                              10, 
                              cmap_range=(0.02, .98), 
                              return_fmt='hex')

sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(18,8.5)})
ax = sns.lineplot(
    x = 'datetime',
    y = 'views',
    hue = 'title',
    data = alltimereps, # Change to topalltime or alltimepeaks
    marker = "o", 
    palette = colors
)

ax.set_xlabel('Year', fontsize=12, family = "Serif")
ax.set_ylabel('View Count', fontsize=12, family = "Serif")
#plt.figure(figsize=(15,6))

# Add suptitle above the title
plt.suptitle("The Temporal Trends of 10 Reptiles with the Highest Peaks\n", fontsize=18, family = 'Serif')
plt.subplots_adjust(top=0.91)

# Add title
#ax.title("Realized by the Python Graph Gallery", color="grey", style='italic')
ax.set_title('English Wikipedia Pageviews, 2015-2020', fontsize = 14, color="grey", style='italic', family = 'Serif')

font = font_manager.FontProperties(family='Serif',
                                   weight='regular',
                                   style='italic', size=11)

#tick_spacing = 1
#ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax.tick_params(axis='x', rotation=0, length = 9, labelsize = 9, left = True)
ax.legend(bbox_to_anchor=(.965, 0.97), loc='upper right', borderaxespad=0, prop=font)
plt.savefig('figures/wiki10peaksreptiles.png', bbox_inches = 'tight')

# %%
year2020 = temporal_wiki.loc[temporal_wiki['Year'].isin([2020])].drop_duplicates("Month").sort_values("Month")
year2019 = temporal_wiki.loc[temporal_wiki['Year'].isin([2019])].drop_duplicates("Month").sort_values("Month")
year2018 = temporal_wiki.loc[temporal_wiki['Year'].isin([2018])].drop_duplicates("Month").sort_values("Month")
year2017 = temporal_wiki.loc[temporal_wiki['Year'].isin([2017])].drop_duplicates("Month").sort_values("Month")
year2016 = temporal_wiki.loc[temporal_wiki['Year'].isin([2016])].drop_duplicates("Month").sort_values("Month")

# %%
import seaborn as sns
import matplotlib.font_manager as font_manager

ax = sns.barplot(
    x = 'Month',
    y = 'views',
    hue = 'scientific_name',
    data = year2020, 
    width = 0.7, palette = 'Set3', dodge = False
)
ax.set_xlabel('Month', fontsize=9)
ax.set_ylabel('WikiPage Views', fontsize=9)


# Add suptitle above the title
plt.suptitle("Most Viewed Species of the Month\n", fontsize=12, family = 'Serif')

# Add title
#ax.title("Realized by the Python Graph Gallery", color="grey", style='italic')
ax.set_title('Page views 2020, English Wiki', fontsize = 10, color="grey", style='italic', family = 'Serif')

font = font_manager.FontProperties(family='Serif',
                                   weight='regular',
                                   style='italic', size=9)

ax.tick_params(axis='x', rotation=0, length = 9, labelsize = 7, left = True)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, prop=font)
#plt.savefig('figures/2020_wikipageviews.png', bbox_inches = 'tight')

# %%
# Read in the CITES data to join with the top 10 (or 20) most reported on species 
cites1 = pd.read_csv("csv/cites1.csv", delimiter = ';')

# Keep only most relevant columns
cites1 = cites1[['Kingdom', 'Class', 'Order', 'Family', 'Genus', 'Species', 'Scientific Name', 'Listing', 'NativeDistributionFullNames', 'Extinct_Distribution']]

cites1 = cites1.rename(columns = {'Scientific Name' : 'scientific_name'})

# Top 20 species in Wikipedia dataset
top20 = wiki.groupby(['title', 'scientific_name'])['views'].sum().nlargest(20).reset_index()

# Merge with the CITES infoset
top20= top20.merge(cites1, on = 'scientific_name', how = 'left').drop_duplicates().reset_index(drop=True)

# %%
import seaborn as sns
palette = {"Mammalia": "#8dd3c7", "Reptilia": "#bebada", "Aves": "#ffffb3"}

ax = sns.barplot(
    x = 'title',
    y = 'views',
    hue = 'Class',
    data = top20, 
    width = 0.7, palette = palette, dodge = False
)
ax.set_xlabel('Species: Common Name', fontsize=16, family = "Serif")
ax.set_ylabel('WikiPage Views', fontsize=16, family = "Serif")


# Add suptitle above the title
plt.suptitle("Top 20 Species by Wikipedia Page Views\n", fontsize=18, family= 'Serif')
plt.subplots_adjust(top=0.94)

# Add title
ax.set_title('Page views 2015-2020, English Wiki', fontsize = 14, color="grey", style='italic', family = 'Serif')



font = font_manager.FontProperties(family='Serif',
                                  weight='regular',
                                  style='italic', size=14)

#fontProperties = {'family': 'Serif', 'color':  'k', 'weight': 'normal', 'style':'italic', 'size': 12}
    
for label in ax.get_xticklabels():
    label.set_fontproperties(font)


ax.tick_params(axis='x', rotation=85, length = 9, labelsize = 14, left = True)
ax.legend(bbox_to_anchor=(0.8, 0.95), loc='upper left', borderaxespad=0, prop=font)
plt.savefig('figures/top_20_species_wiki.png', bbox_inches = 'tight')

# %% [markdown]
# ### Investigation of article content by year-month and species

# %%
# Read in the processed dataframe
alltext = pd.read_csv("alltext-no-engagement-sentimet.csv", sep = ";")
len(alltext)
# Out:
# 13066

# %%
alltext["date"] = pd.to_datetime(alltext['date'])

# %%
## alltimepeaks stored with 10 species with highest peaks in wikipageviews over a 5 year timespan
# we will fetch the dates with the most notable peaks and look for article content in the same time
# since it is difficult to know what causes a peak and its connection to the media we will investigate 
# the article content of one month prior and one month after in addition to the month in question 

speciespeaks = alltimepeaks.groupby('scientific_name')['views'].nlargest(1).reset_index().drop(columns = "level_1")

# %%
excerpt = alltimepeaks.loc[alltimepeaks['views'].isin(speciespeaks['views'])].reset_index(drop = True)

# %%
# Assuming df1 and df2 are your dataframes

# Extract the year and month from the 'datetime' column in df1
alltext['year'] = pd.to_datetime(alltext['date']).dt.year
alltext['month'] = pd.to_datetime(alltext['date']).dt.month

# Extract the year and month from the 'date' column in df2
excerpt['year'] = pd.to_datetime(excerpt['datetime']).dt.year
excerpt['month'] = pd.to_datetime(excerpt['datetime']).dt.month

# %%
df1 = excerpt.copy()

# %%
# Create an empty dataframe to store the new rows
new_rows = pd.DataFrame(columns=df1.columns)

# Iterate over each species in df1
for index, row in df1.iterrows():
    species_month = row['month']
    species_year = row['year']
    
    # Calculate the adjacent months
    prev_month = species_month - 1
    next_month = species_month + 1
    
    # Create two new rows with adjusted months
    prev_row = row.copy()
    prev_row['month'] = prev_month
    prev_row['datetime'] = pd.to_datetime(f"{species_year}-{prev_month}-01")
    
    next_row = row.copy()
    next_row['month'] = next_month
    next_row['datetime'] = pd.to_datetime(f"{species_year}-{next_month}-01")
    
    # Append the new rows to the dataframe
    new_rows = new_rows.append(prev_row)
    new_rows = new_rows.append(next_row)

# Concatenate the original dataframe with the new rows
df1 = pd.concat([df1, new_rows], ignore_index=True)

# Sort the dataframe by scientific_name and datetime
df1 = df1.sort_values(['scientific_name', 'datetime'])

# Reset the index
df1 = df1.reset_index(drop=True)

# Print the updated dataframe
df1
# Out:
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
# /tmp/ipykernel_44/2456268825.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(prev_row)
# /tmp/ipykernel_44/2456268825.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows = new_rows.append(next_row)
#                               title   views         scientific_name  \
# 0   Giant golden-crowned flying fox  347925        Acerodon jubatus
# 1   Giant golden-crowned flying fox  347925        Acerodon jubatus
# 2   Giant golden-crowned flying fox  347925        Acerodon jubatus
# 3                       Giant panda  411539  Ailuropoda melanoleuca
# 4                       Giant panda  411539  Ailuropoda melanoleuca
# 5                       Giant panda  411539  Ailuropoda melanoleuca
# 6                         Red panda  652891         Ailurus fulgens
# 7                         Red panda  652891         Ailurus fulgens
# 8                         Red panda  652891         Ailurus fulgens
# 9                        Blue whale  328964   Balaenoptera musculus
# 10                       Blue whale  328964   Balaenoptera musculus
# 11                       Blue whale  328964   Balaenoptera musculus
# 12                 White rhinoceros  320876     Ceratotherium simum
# 13                 White rhinoceros  320876     Ceratotherium simum
# 14                 White rhinoceros  320876     Ceratotherium simum
# 15                 Peregrine falcon  431655        Falco peregrinus
# 16                 Peregrine falcon  431655        Falco peregrinus
# 17                 Peregrine falcon  431655        Falco peregrinus
# 18                         Mandrill  350692       Mandrillus sphinx
# 19                         Mandrill  350692       Mandrillus sphinx
# 20                         Mandrill  350692       Mandrillus sphinx
# 21                             Lion  574872            Panthera leo
# 22                             Lion  574872            Panthera leo
# 23                             Lion  574872            Panthera leo
# 24                           Jaguar  353949           Panthera onca
# 25                           Jaguar  353949           Panthera onca
# 26                           Jaguar  353949           Panthera onca
# 27                            Tiger  694465         Panthera tigris
# 28                            Tiger  694465         Panthera tigris
# 29                            Tiger  694465         Panthera tigris
#
#      datetime   Kingdom     Class           Order           Family  \
# 0  2020-05-01  Animalia  Mammalia      Chiroptera     Pteropodidae
# 1  2020-06-01  Animalia  Mammalia      Chiroptera     Pteropodidae
# 2  2020-07-01  Animalia  Mammalia      Chiroptera     Pteropodidae
# 3  2020-02-01  Animalia  Mammalia       Carnivora          Ursidae
# 4  2020-03-01  Animalia  Mammalia       Carnivora          Ursidae
# 5  2020-04-01  Animalia  Mammalia       Carnivora          Ursidae
# 6  2017-04-01  Animalia  Mammalia       Carnivora        Ailuridae
# 7  2017-05-01  Animalia  Mammalia       Carnivora        Ailuridae
# 8  2017-06-01  Animalia  Mammalia       Carnivora        Ailuridae
# 9  2019-04-01  Animalia  Mammalia         Cetacea  Balaenopteridae
# 10 2019-05-01  Animalia  Mammalia         Cetacea  Balaenopteridae
# 11 2019-06-01  Animalia  Mammalia         Cetacea  Balaenopteridae
# 12 2018-02-01  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 13 2018-03-01  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 14 2018-04-01  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 15 2016-07-01  Animalia      Aves   Falconiformes       Falconidae
# 16 2016-08-01  Animalia      Aves   Falconiformes       Falconidae
# 17 2016-09-01  Animalia      Aves   Falconiformes       Falconidae
# 18 2018-10-01  Animalia  Mammalia        Primates  Cercopithecidae
# 19 2018-11-01  Animalia  Mammalia        Primates  Cercopithecidae
# 20 2018-12-01  Animalia  Mammalia        Primates  Cercopithecidae
# 21 2017-02-01  Animalia  Mammalia       Carnivora          Felidae
# 22 2017-03-01  Animalia  Mammalia       Carnivora          Felidae
# 23 2017-04-01  Animalia  Mammalia       Carnivora          Felidae
# 24 2017-01-01  Animalia  Mammalia       Carnivora          Felidae
# 25 2017-02-01  Animalia  Mammalia       Carnivora          Felidae
# 26 2017-03-01  Animalia  Mammalia       Carnivora          Felidae
# 27 2020-02-01  Animalia  Mammalia       Carnivora          Felidae
# 28 2020-03-01  Animalia  Mammalia       Carnivora          Felidae
# 29 2020-04-01  Animalia  Mammalia       Carnivora          Felidae
#
#             Genus      Species  year month
# 0        Acerodon      jubatus  2020     5
# 1        Acerodon      jubatus  2020     6
# 2        Acerodon      jubatus  2020     7
# 3      Ailuropoda  melanoleuca  2020     2
# 4      Ailuropoda  melanoleuca  2020     3
# 5      Ailuropoda  melanoleuca  2020     4
# 6         Ailurus      fulgens  2017     4
# 7         Ailurus      fulgens  2017     5
# 8         Ailurus      fulgens  2017     6
# 9    Balaenoptera     musculus  2019     4
# 10   Balaenoptera     musculus  2019     5
# 11   Balaenoptera     musculus  2019     6
# 12  Ceratotherium        simum  2018     2
# 13  Ceratotherium        simum  2018     3
# 14  Ceratotherium        simum  2018     4
# 15          Falco   peregrinus  2016     7
# 16          Falco   peregrinus  2016     8
# 17          Falco   peregrinus  2016     9
# 18     Mandrillus       sphinx  2018    10
# 19     Mandrillus       sphinx  2018    11
# 20     Mandrillus       sphinx  2018    12
# 21       Panthera          leo  2017     2
# 22       Panthera          leo  2017     3
# 23       Panthera          leo  2017     4
# 24       Panthera         onca  2017     1
# 25       Panthera         onca  2017     2
# 26       Panthera         onca  2017     3
# 27       Panthera       tigris  2020     2
# 28       Panthera       tigris  2020     3
# 29       Panthera       tigris  2020     4

# %%
# Merge df1 and df2 based on scientific_name, year, and month
merged_df = pd.merge(alltext, df1[['scientific_name', 'year', 'month', 'views']], on=['scientific_name'])

# %%
# Filter the merged dataframe to include only the specific month and year
filtered_df = merged_df[(merged_df['month_x'] == merged_df['month_y']) & (merged_df['year_x'] == merged_df['year_y'])]

filtered_df
# Out:
#                     common_name         scientific_name  \
# 39                 Lesser Panda         Ailurus fulgens
# 43                 Lesser Panda         Ailurus fulgens
# 460                Asiatic Lion            Panthera leo
# 464                 Indian Lion            Panthera leo
# 957              Siberian Tiger         Panthera tigris
# 960                  Amur Tiger         Panthera tigris
# 963                  Amur Tiger         Panthera tigris
# 966                  Amur Tiger         Panthera tigris
# 970                  Amur Tiger         Panthera tigris
# 974                  Amur Tiger         Panthera tigris
# 977                  Amur Tiger         Panthera tigris
# 980                  Amur Tiger         Panthera tigris
# 983                       Tiger         Panthera tigris
# 986                       Tiger         Panthera tigris
# 989                       Tiger         Panthera tigris
# 992                  Amur Tiger         Panthera tigris
# 995                       Tiger         Panthera tigris
# 998                  Amur Tiger         Panthera tigris
# 1001                 Amur Tiger         Panthera tigris
# 1004                 Amur Tiger         Panthera tigris
# 1007             Siberian Tiger         Panthera tigris
# 1010                 Amur Tiger         Panthera tigris
# 1013                      Tiger         Panthera tigris
# 1016             Siberian Tiger         Panthera tigris
# 1019                 Amur Tiger         Panthera tigris
# 1022             Siberian Tiger         Panthera tigris
# 1025                      Tiger         Panthera tigris
# 1028             Siberian Tiger         Panthera tigris
# 1031                      Tiger         Panthera tigris
# 1034                      Tiger         Panthera tigris
# 1162           White Rhinoceros     Ceratotherium simum
# 1165   Square-lipped Rhinoceros     Ceratotherium simum
# 1168           White Rhinoceros     Ceratotherium simum
# 1171           White Rhinoceros     Ceratotherium simum
# 1175           White Rhinoceros     Ceratotherium simum
# 1390                Giant Panda  Ailuropoda melanoleuca
# 1393                Giant Panda  Ailuropoda melanoleuca
# 1396                Giant Panda  Ailuropoda melanoleuca
# 1399                Giant Panda  Ailuropoda melanoleuca
# 1402                Giant Panda  Ailuropoda melanoleuca
# 1405                Giant Panda  Ailuropoda melanoleuca
# 1408                Giant Panda  Ailuropoda melanoleuca
# 1412                Giant Panda  Ailuropoda melanoleuca
# 1415                Giant Panda  Ailuropoda melanoleuca
# 1418                Giant Panda  Ailuropoda melanoleuca
# 1421                Giant Panda  Ailuropoda melanoleuca
# 1424                Giant Panda  Ailuropoda melanoleuca
# 1463                 Blue Whale   Balaenoptera musculus
#
#                                            distribution      iucn_status  \
# 39    Bhutan, China, India, Lao People's Democratic ...               EN
# 43    Bhutan, China, India, Lao People's Democratic ...               EN
# 460   Afghanistan, Algeria, Angola, Benin, Botswana,...               VU
# 464   Afghanistan, Algeria, Angola, Benin, Botswana,...               VU
# 957   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 960   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 963   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 966   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 970   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 974   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 977   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 980   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 983   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 986   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 989   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 992   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 995   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 998   Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1001  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1004  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1007  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1010  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1013  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1016  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1019  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1022  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1025  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1028  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1031  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1034  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 1162  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 1165  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 1168  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 1171  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 1175  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 1390                                              China               VU
# 1393                                              China               VU
# 1396                                              China               VU
# 1399                                              China               VU
# 1402                                              China               VU
# 1405                                              China               VU
# 1408                                              China               VU
# 1412                                              China               VU
# 1415                                              China               VU
# 1418                                              China               VU
# 1421                                              China               VU
# 1424                                              China               VU
# 1463  Angola, Antarctica, Argentina, Australia, Bang...               EN
#
#       date_saved   Kingdom     Class           Order           Family  \
# 39    2020-06-18  Animalia  Mammalia       Carnivora        Ailuridae
# 43    2020-06-18  Animalia  Mammalia       Carnivora        Ailuridae
# 460   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 464   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 957   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 960   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 963   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 966   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 970   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 974   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 977   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 980   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 983   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 986   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 989   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 992   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 995   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 998   2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1001  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1004  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1007  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1010  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1013  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1016  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1019  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1022  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1025  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1028  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1031  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1034  2020-06-18  Animalia  Mammalia       Carnivora          Felidae
# 1162  2020-06-18  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 1165  2020-06-18  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 1168  2020-06-18  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 1171  2020-06-18  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 1175  2020-06-18  Animalia  Mammalia  Perissodactyla   Rhinocerotidae
# 1390  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1393  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1396  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1399  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1402  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1405  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1408  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1412  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1415  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1418  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1421  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1424  2020-06-18  Animalia  Mammalia       Carnivora          Ursidae
# 1463  2020-06-18  Animalia  Mammalia         Cetacea  Balaenopteridae
#
#               Genus  ...                                               link  \
# 39          Ailurus  ...  https://news.google.com/articles/CBMiXGh0dHBzO...
# 43          Ailurus  ...  https://news.google.com/articles/CBMiOWh0dHBzO...
# 460        Panthera  ...  https://news.google.com/articles/CBMiemh0dHBzO...
# 464        Panthera  ...  https://news.google.com/articles/CBMiaGh0dHBzO...
# 957        Panthera  ...  https://news.google.com/articles/CBMiX2h0dHBzO...
# 960        Panthera  ...  https://news.google.com/articles/CAIiEEx-Q_9pf...
# 963        Panthera  ...  https://news.google.com/articles/CAIiEE6FA5bMk...
# 966        Panthera  ...  https://news.google.com/articles/CBMifmh0dHBzO...
# 970        Panthera  ...  https://news.google.com/articles/CBMiQ2h0dHBzO...
# 974        Panthera  ...  https://news.google.com/articles/CAIiEHqzFVAUF...
# 977        Panthera  ...  https://news.google.com/articles/CBMiUGh0dHBzO...
# 980        Panthera  ...  https://news.google.com/articles/CBMiR2h0dHBzO...
# 983        Panthera  ...  https://news.google.com/articles/CAIiEHgNRUtEu...
# 986        Panthera  ...  https://news.google.com/articles/CBMiVWh0dHBzO...
# 989        Panthera  ...  https://news.google.com/articles/CBMiQGh0dHBzO...
# 992        Panthera  ...  https://news.google.com/articles/CBMiQ2h0dHBzO...
# 995        Panthera  ...  https://news.google.com/articles/CAIiEBaRebxIi...
# 998        Panthera  ...  https://news.google.com/articles/CBMiXmh0dHBzO...
# 1001       Panthera  ...  https://news.google.com/articles/CAIiEHWMvcpm6...
# 1004       Panthera  ...  https://news.google.com/articles/CBMiXmh0dHBzO...
# 1007       Panthera  ...  https://news.google.com/articles/CBMicmh0dHBzO...
# 1010       Panthera  ...  https://news.google.com/articles/CBMiXWh0dHBzO...
# 1013       Panthera  ...  https://news.google.com/articles/CAIiEEOSeWwf5...
# 1016       Panthera  ...  https://news.google.com/articles/CBMicGh0dHBzO...
# 1019       Panthera  ...  https://news.google.com/articles/CBMiR2h0dHBzO...
# 1022       Panthera  ...  https://news.google.com/articles/CAIiECVsHJHE5...
# 1025       Panthera  ...  https://news.google.com/articles/CAIiEBsb9IYpi...
# 1028       Panthera  ...  https://news.google.com/articles/CBMicmh0dHBzO...
# 1031       Panthera  ...  https://news.google.com/articles/CAIiEMdqq7TmI...
# 1034       Panthera  ...  https://news.google.com/articles/CBMiRWh0dHBzO...
# 1162  Ceratotherium  ...  https://news.google.com/articles/CBMiXGh0dHBzO...
# 1165  Ceratotherium  ...  https://news.google.com/articles/CAIiEIDHbikSr...
# 1168  Ceratotherium  ...  https://news.google.com/articles/CBMiZWh0dHBzO...
# 1171  Ceratotherium  ...  https://news.google.com/articles/CBMiYWh0dHBzO...
# 1175  Ceratotherium  ...  https://news.google.com/articles/CBMiXWh0dHBzO...
# 1390     Ailuropoda  ...  https://news.google.com/articles/CBMiR2h0dHBzO...
# 1393     Ailuropoda  ...  https://news.google.com/articles/CBMiPGh0dHBzO...
# 1396     Ailuropoda  ...  https://news.google.com/articles/CBMiRmh0dHBzO...
# 1399     Ailuropoda  ...  https://news.google.com/articles/CBMiamh0dHBzO...
# 1402     Ailuropoda  ...  https://news.google.com/articles/CBMib2h0dHBzO...
# 1405     Ailuropoda  ...  https://news.google.com/articles/CBMiU2h0dHBzO...
# 1408     Ailuropoda  ...  https://news.google.com/articles/CBMiZmh0dHBzO...
# 1412     Ailuropoda  ...  https://news.google.com/articles/CAIiEAAqBh078...
# 1415     Ailuropoda  ...  https://news.google.com/articles/CBMiK2h0dHBzO...
# 1418     Ailuropoda  ...  https://news.google.com/articles/CBMiSmh0dHA6L...
# 1421     Ailuropoda  ...  https://news.google.com/articles/CBMiNGh0dHA6L...
# 1424     Ailuropoda  ...  https://news.google.com/articles/CBMiVmh0dHBzO...
# 1463   Balaenoptera  ...  https://news.google.com/articles/CBMicGh0dHBzO...
#
#                                                   image       date  \
# 39    https://america.cgtn.com/wp-content/uploads/20... 2017-04-29
# 43                                                  NaN 2017-05-24
# 460   https://images.livemint.com/rf/Image-621x414/L... 2017-03-17
# 464   https://i.dailymail.co.uk/i/pix/2017/04/27/02/... 2017-04-27
# 957   https://www.worldatlas.com/r/w1200-h701-c1200x... 2020-02-06
# 960   https://imgs.mongabay.com/wp-content/uploads/s... 2020-02-13
# 963   https://i2-prod.somersetlive.co.uk/incoming/ar... 2020-02-23
# 966   https://cdn.images.express.co.uk/img/dynamic/7... 2020-02-26
# 970   https://s.yimg.com/uu/api/res/1.2/aGw3q_cvkTbM... 2020-03-11
# 974   https://www.nationalgeographic.com/content/dam... 2020-04-01
# 977   https://images.theconversation.com/files/32510... 2020-04-04
# 980   https://s.yimg.com/uu/api/res/1.2/DQ7UCmXVpuX8... 2020-04-06
# 983   https://www.outsideonline.com/sites/default/fi... 2020-04-09
# 986   https://www.marinij.com/wp-content/uploads/202... 2020-04-13
# 989   https://cdn.mos.cms.futurecdn.net/M6NX3fodbvcv... 2020-04-15
# 992   https://i0.wp.com/media.boingboing.net/wp-cont... 2020-04-15
# 995   https://i.insider.com/5e983486d5873a395604cbd3... 2020-04-16
# 998   https://nepascene.com/wp-content/uploads/2020/... 2020-04-16
# 1001  https://i.dailymail.co.uk/1s/2020/04/16/11/272... 2020-04-16
# 1004  https://img.youtube.com/vi/P53A7drj_II/hqdefau... 2020-04-17
# 1007  https://thehill.com/sites/default/files/white_... 2020-04-17
# 1010  https://www.gazetteandherald.co.uk/resources/i... 2020-04-17
# 1013  https://imgs.mongabay.com/wp-content/uploads/s... 2020-04-20
# 1016  https://static.euronews.com/articles/stories/0... 2020-04-21
# 1019  https://s.yimg.com/uu/api/res/1.2/2KlXwMY2kMAY... 2020-04-21
# 1022  https://apicms.thestar.com.my/uploads/images/2... 2020-04-21
# 1025  https://www.washingtonpost.com/resizer/CSpt66e... 2020-04-21
# 1028  https://www.surreynowleader.com/wp-content/upl... 2020-04-22
# 1031  https://static.foxnews.com/foxnews.com/content... 2020-04-29
# 1034  https://golf.com/wp-content/uploads/2020/04/Ti... 2020-04-29
# 1162  https://www.nationalgeographic.com/content/dam... 2018-03-02
# 1165  https://images.financialexpress.com/2018/03/ro... 2018-03-20
# 1168  https://www.nationalgeographic.com/content/dam... 2018-03-20
# 1171  https://www.nationalgeographic.com/content/dam... 2018-03-31
# 1175  https://images.theconversation.com/files/21343... 2018-04-05
# 1390  https://www.rd.com/wp-content/uploads/2020/03/... 2020-03-02
# 1393  https://hips.hearstapps.com/hmg-prod.s3.amazon... 2020-03-12
# 1396  https://nationalzoo.si.edu/sites/default/files... 2020-03-16
# 1399  https://nationalzoo.si.edu/sites/default/files... 2020-03-23
# 1402  https://media.nbcwashington.com/2019/09/GettyI... 2020-03-24
# 1405  https://thedcpost.com/wp-content/uploads/2020/... 2020-03-24
# 1408  https://s3.amazonaws.com/ocn-media/e69c758e-69... 2020-03-25
# 1412  https://i.guim.co.uk/img/media/edb817845a9aac8... 2020-04-07
# 1415  https://obj.shine.cn/files/2020/04/25/fde7164f... 2020-04-25
# 1418  https://img2.chinadaily.com.cn/images/202004/2... 2020-04-27
# 1421                                                NaN 2020-04-29
# 1424  https://www.designboom.com/wp-content/uploads/... 2020-04-30
# 1463  https://ewscripps.brightspotcdn.com/dims4/defa... 2019-06-28
#
#                                                     ner sentiment year_x  \
# 39    [{'sent': 'Click to share on Weibo (Opens in n...  Positive   2017
# 43    [{'sent': 'Yogesh Rana Magar\n\n', 'ents': {'P...  Negative   2017
# 460   [{'sent': 'New Delhi: The lion population in a...  Positive   2017
# 464   [{'sent': 'One lion did not appreciate being t...  Negative   2017
# 957   [{'sent': 'WorldAtlas.com (the “Website”) is o...  Positive   2020
# 960   [{'sent': 'For the first time ever, scientists...  Negative   2020
# 963   [{'sent': 'Sign up to FREE email alerts from S...  Positive   2020
# 966   [{'sent': 'FREE now and never miss the top Roy...  Negative   2020
# 970   [{'sent': 'Denver Zoo’s resident Amur tiger Ni...  Positive   2020
# 974   [{'sent': 'Netflix’s recent documentary minise...  Positive   2020
# 977   [{'sent': 'Featuring eccentric characters with...  Positive   2020
# 980   [{'sent': 'Denver Zoo in Colorado is providing...  Positive   2020
# 983   [{'sent': 'Five minutes into the first episode...  Positive   2020
# 986   [{'sent': 'One show, in particular, seems to h...  Positive   2020
# 989   [{'sent': 'Joe Exotic, featured in the Netflix...  Positive   2020
# 992   [{'sent': 'Russian driver encounters rare enda...  Positive   2020
# 995   [{'sent': 'Conservation biologist Imogene Canc...  Negative   2020
# 998   [{'sent': '‘Tiger King’ only scratches surface...  Positive   2020
# 1001  [{'sent': "Longleat Safari Park released candi...  Positive   2020
# 1004  [{'sent': "The Amur tiger is protected by Russ...  Positive   2020
# 1007  [{'sent': 'The most popular show on Netflix ha...  Negative   2020
# 1010  [{'sent': 'LONGLEAT keeper Caleb Hall has shar...  Positive   2020
# 1013  [{'sent': 'A new scientific survey provides ev...  Negative   2020
# 1016  [{'sent': 'The number of captive tigers in Eur...  Negative   2020
# 1019  [{'sent': 'Denver Zoo is providing daily updat...  Negative   2020
# 1022  [{'sent': 'Dr John Goodrich was researching Si...  Positive   2020
# 1025  [{'sent': 'The Wild Animal Sanctuary near Keen...  Negative   2020
# 1028  [{'sent': 'The Greater Vancouver zoo has one S...  Positive   2020
# 1031  [{'sent': 'is raising new questions over the n...  Positive   2020
# 1034  [{'sent': 'The craziest Tiger Woods comeback y...  Positive   2020
# 1162  [{'sent': 'But now, the health of this rare rh...  Negative   2018
# 1165  [{'sent': 'Rohit Sharma expresses his sadness ...  Positive   2018
# 1168  [{'sent': "Conservationists were expecting the...  Positive   2018
# 1171  [{'sent': 'The world mourned after Sudan, the ...  Negative   2018
# 1175  [{'sent': 'A geriatric semi-captive rhino died...  Positive   2018
# 1390  [{'sent': 'Other reasons the panda population ...  Positive   2020
# 1393  [{'sent': 'Listed as vulnerable by the IUCN Re...  Positive   2020
# 1396  [{'sent': 'Here at the Smithsonian’s National ...  Positive   2020
# 1399  [{'sent': 'A team of reproductive scientists, ...  Positive   2020
# 1402  [{'sent': 'Cross your fingers for a baby panda...  Positive   2020
# 1405  [{'sent': 'The beloved giant panda of the Smit...  Positive   2020
# 1408  [{'sent': 'It will take 3-6 months to find out...  Positive   2020
# 1412  [{'sent': 'A middle-aged couple of giant panda...  Positive   2020
# 1415  [{'sent': 'A 6-month-old giant panda met visit...  Positive   2020
# 1418  [{'sent': 'The baby panda with his mother Jia ...  Positive   2020
# 1421  [{'sent': 'Giant panda toddler on view in Shan...  Positive   2020
# 1424  [{'sent': 'to be installed this year in dujian...  Positive   2020
# 1463  [{'sent': 'SAN DIEGO (KGTV) —', 'ents': {'GPE'...  Positive   2019
#
#      month_x year_y month_y   views
# 39         4   2017       4  652891
# 43         5   2017       5  652891
# 460        3   2017       3  574872
# 464        4   2017       4  574872
# 957        2   2020       2  694465
# 960        2   2020       2  694465
# 963        2   2020       2  694465
# 966        2   2020       2  694465
# 970        3   2020       3  694465
# 974        4   2020       4  694465
# 977        4   2020       4  694465
# 980        4   2020       4  694465
# 983        4   2020       4  694465
# 986        4   2020       4  694465
# 989        4   2020       4  694465
# 992        4   2020       4  694465
# 995        4   2020       4  694465
# 998        4   2020       4  694465
# 1001       4   2020       4  694465
# 1004       4   2020       4  694465
# 1007       4   2020       4  694465
# 1010       4   2020       4  694465
# 1013       4   2020       4  694465
# 1016       4   2020       4  694465
# 1019       4   2020       4  694465
# 1022       4   2020       4  694465
# 1025       4   2020       4  694465
# 1028       4   2020       4  694465
# 1031       4   2020       4  694465
# 1034       4   2020       4  694465
# 1162       3   2018       3  320876
# 1165       3   2018       3  320876
# 1168       3   2018       3  320876
# 1171       3   2018       3  320876
# 1175       4   2018       4  320876
# 1390       3   2020       3  411539
# 1393       3   2020       3  411539
# 1396       3   2020       3  411539
# 1399       3   2020       3  411539
# 1402       3   2020       3  411539
# 1405       3   2020       3  411539
# 1408       3   2020       3  411539
# 1412       4   2020       4  411539
# 1415       4   2020       4  411539
# 1418       4   2020       4  411539
# 1421       4   2020       4  411539
# 1424       4   2020       4  411539
# 1463       6   2019       6  328964
#
# [48 rows x 26 columns]

# %%
filtered_df = filtered_df.sort_values(by="date").reset_index(drop=True)

# %%
filtered_df.to_csv("wikipagepeaks-articles.csv", sep = ";", index = False)

# %% [markdown]
# ### Google Hits

# %%
#google = pd.read_csv("csv/google_hits_species.csv", sep = ";")
#google = google.drop_duplicates().reset_index(drop = True)
top20google = speciesinfo.nlargest(columns = "hits_renew", n = 20)

# %%
import seaborn as sns
import matplotlib.font_manager as font_manager
import matplotlib.ticker as ticker

palette = {"Mammalia": "#8dd3c7", "Aves": "#ffffb3", "Reptilia": "#bebada"}

sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(14,12)})
ax = sns.barplot(
    x = 'title',
    y = 'hits_renew',
    hue = 'Class',
    data = top20google, 
    width = 0.7, 
    palette = palette, 
    dodge = False
)

ax.set_xlabel('Species: Common Name', fontsize=16, family = "Serif")
ax.set_ylabel('Google Hits', fontsize=16, family = "Serif")
#ax.set_yscale('log')


# Add suptitle 
plt.title("Top 20 Species by Google Search Results", fontsize=18, family = 'Serif')
plt.subplots_adjust(top=0.80)


font = font_manager.FontProperties(family='Serif',
                                   weight='regular',
                                   style='italic', size=14)
    
for label in ax.get_xticklabels():
    label.set_fontproperties(font)


ax.tick_params(axis='x', rotation=85, length = 9, labelsize = 14, left = True)
ax.legend(bbox_to_anchor=(0.8, 0.95), loc='upper left', borderaxespad=0, prop=font)
#plt.savefig('figures/top_20_species_google.png', bbox_inches = 'tight')
