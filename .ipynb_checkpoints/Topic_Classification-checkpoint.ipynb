# %% [markdown]
# # Text Processing and Classification

# %%
import pandas as pd
#import geopandas as gpd
import json
from ast import literal_eval
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import json
import base64
#pip install geopandas
#pip install spacy
#python -m spacy download en_core_web_lg

# %%
df = pd.read_csv("articles-w-full_engagement.csv", sep = "~")
df = df.drop(columns = ["date_saved", "sharecount"])

# %%
df = pd.read_csv("articles-w-full_engagement.csv", sep = "~")
df = df.drop(columns = ["date_saved", "sharecount"])

alltimepeaks = pd.read_csv("csv/wiki-10alltimepeaks.csv", sep = ";")

# Turn the species in the wiki all time peaks into a list 
peaks = list(alltimepeaks['scientific_name'].unique())
# Using the list create a subset dataframe from these species and reset index
news_filtered = df.loc[df['scientific_name'].isin(peaks)].reset_index(drop = True)

# Make sure date is stored as datetime
news_filtered['date'] = pd.to_datetime(news_filtered['date'])
# More filters and grouping
news_filtered = news_filtered.loc[news_filtered.date.dt.year > 2014].reset_index(drop=True)


news = news_filtered.groupby([(news_filtered.date.dt.year), (news_filtered.date.dt.month), (news_filtered.scientific_name)])['shares'].sum()\
        .sort_values(ascending=False).rename_axis(["Year", "Month", "scientific_name"]).reset_index()

# %% [markdown]
# ### NLTK and Geonamescache

# %%
import re
import string
from bs4 import BeautifulSoup
import nltk # pip install nltk
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import spacy 
# pip install spacy
# Out:
# 2023-04-25 12:09:17.776114: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 12:09:18.059083: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-25 12:09:18.059157: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-25 12:09:18.117829: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-04-25 12:09:19.401902: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-25 12:09:19.402183: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-25 12:09:19.402207: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-04-25 12:09:20.885839: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-25 12:09:20.885942: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-25 12:09:20.886017: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (nb-shaneka-the-orange-84869b6966-l5ss9): /proc/driver/nvidia/version does not exist

# %%
import geonamescache
# pip install geonamescache
gc = geonamescache.GeonamesCache()

# gets nested dictionary for countries
countries = gc.get_countries()

# To avoid tensorflow warnings 
TF_CPP_MIN_LOG_LEVEL="2"
nlp = spacy.load('en_core_web_lg')

# Create a new column named 'processed_txt'
#df['processed_txt'] = None

# Apply the language model under 'nlp' to the contents of the DataFrame column 'text'
#df['processed_txt'] = df['text'].apply(nlp)

# %%
nltk.download('stopwords')
nltk.download('wordnet')
#Function retrieved from https://www.dataknowsall.com/textcleaning.html

def clean_string(text, stem="None"):

    final_string = ""

    # Make lower
    text = text.lower()

    # Remove line breaks
    text = re.sub(r'\n', '', text)

    # Remove puncuation
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    # Remove stop words
    text = text.split()
    useless_words = nltk.corpus.stopwords.words("english")
    useless_words = useless_words + ['also', 'said', 'would', 'could', 'should', 'told', 'say', 'like', 'u', 
                                     'see', 'day', 'since', 'red', 'often', 'one', 'two', 'time', 'animal', 'tiger', 'lion', 'elephant',
                                    'panda', 'species', 'rhino', "—"]

    text_filtered = [word for word in text if not word in useless_words]

    # Remove numbers
    text_filtered = [re.sub(r'\w*\d\w*', '', w) for w in text_filtered]

    # Stem or Lemmatize
    if stem == 'Stem':
        stemmer = PorterStemmer() 
        text_stemmed = [stemmer.stem(y) for y in text_filtered]
    elif stem == 'Lem':
        lem = WordNetLemmatizer()
        text_stemmed = [lem.lemmatize(y) for y in text_filtered]
    elif stem == 'Spacy':
        text_filtered = nlp(' '.join(text_filtered))
        text_stemmed = [y.lemma_ for y in text_filtered]
    else:
        text_stemmed = text_filtered

    final_string = ' '.join(text_stemmed)

    return final_string


# Sample application of function
df['text_clean'] = df['text'].apply(lambda x: clean_string(x, stem='Lem'))

# Apply the language model under 'nlp' to the contents of the DataFrame column 'text'
#rizz_media['spacy'] = rizz_media['text_clean_spcy'].apply(nlp)
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Obtained from https://stackoverflow.com/questions/59444065/differentiate-between-countries-and-cities-in-spacy-ner/59458133#59458133

def gen_dict_extract(var, key):
    if isinstance(var, dict):
        for k, v in var.items():
            if k == key:
                yield v
            if isinstance(v, (dict, list)):
                yield from gen_dict_extract(v, key)
    elif isinstance(var, list):
        for d in var:
            yield from gen_dict_extract(d, key)
            
countries = [*gen_dict_extract(countries, 'name')]   
countries = [txt.lower() for txt in countries]

# %%
# Define a function named 'get_ents' that takes spacy text and the spacy label
# We refer to this input using the variable name 'nlp_text'.
def get_ents(nlp_text, label):
    
    # First we make sure that the input is of correct type
    # by using the assert command to check the input type
    assert type(nlp_text) == spacy.tokens.doc.Doc
    
    # Let's set up a placeholder list for our ne's
    ents = []
    
    # We begin then begin looping over the Doc object
    for ent in nlp_text.ents:
        if (ent.label_ == label):
            if ent.text in countries: # if the word is a country name
                ents.append(ent.text) # Append the ent text to the list of ents to return
            
    # When the loop is complete, return the list of ents
    return ents

# %%
# Create a new column named 'processed_txt'
df['processed_txt'] = None

# Apply the language model under 'nlp' to the contents of the DataFrame column 'text'
df['processed_txt'] = df['text_clean'].apply(nlp)

# %%
# Apply the 'get_ents' function to the column 'processed_txt'
# Store as a separate lists all values tagged with GPE
gpe_list = []

for i in df['processed_txt']:
    x = get_ents(i, "GPE")
    gpe_list.append(x)

# %%
for i in df['processed_txt']:
    for ent in i.ents:
          print(ent, ent.label_)
    
          break
# Out:
# tempoco jakarta GPE
# tempoco jakarta director biodiversity conservation ministry environment forestry ORG
# east lampung LOC
# tempoco nairobi ORG
# tempoco phnom penh GPE
# jakarta GPE
# tempoco GPE
# louisiana coastal ORG
# yasmeen banuin PERSON
# sharea grevy PERSON
# korea GPE
# ten CARDINAL
# sodwana bay FAC
# kelly dolphin PERSON
# today DATE
# alex kirbybbc PERSON
# helen briggsbbc PERSON
# many half CARDINAL
# first ORDINAL
# przewalski NORP
# alex kirbybbc PERSON
# east kallmantanpreviously PERSON
# madagascarrhettt butler mongabaycommay PRODUCT
# three CARDINAL
# asian NORP
# matthew wellsbbc PERSON
# catfish legaltina butler mongabaycomjune ORG
# nearly nine foot long  meter QUANTITY
# compoundstina ORG
# thursday DATE
# madagascar lemur ORG
# hungerrhett butlerjuly PERSON
# u germany ORG
# amazonancient ORG
# releaseseptember ORG
# richard blackenvironment PERSON
# whythe ORG
# helen briggsbbc PERSON
# three CARDINAL
# friday DATE
# san diego kgtv GPE
# middle wildebeest LOC
# new york GPE
# casewhatsapp ORG
# amazon ORG
# chimpanzee sanctuary wildlife conservation trust ORG
# max PERSON
# sumatran rhinoceros dicerorhinus FAC
# punjab PERSON
# thailand GPE
# indian NORP
# norman PERSON
# darren griffin mike bruford PERSON
# levelby GPE
# vancouver bc whale ORG
# internetin PERSON
# four CARDINAL
# loggerhead turtle PERSON
# blackandwhite ORG
# falcon ORG
# gozo mediterranean ORG
# five CARDINAL
# sharesby GPE
# chris taylor PERSON
# gozo   PERSON
# irish NORP
# nottinghamshirelive mansfield PERSON
# san diego zoomay ORG
# britain GPE
# taiping taiping PERSON
# new delhi GPE
# anew delhi GPE
# virginia GPE
# lauren PERSON
# swarna prava PERSON
# british NORP
# hollandonsea PERSON
# today DATE
# alert grimsbylive ORG
# wxyz PERSON
# nevada GPE
# peter greer PERSON
# clutch driverdrill PERSON
# pakistani NORP
# wang fu ni PERSON
# charlie crowther dorsetbased PERSON
# asian NORP
# gauhati university’s zoology ORG
# colombo  leopard PERSON
# grizzly sightingsin PERSON
# indian institute ORG
# lonzo PERSON
# countryin ORG
# smithsonian conservation biology institute ORG

# %%
# Create a daatframe from the countries list 
gpe_df = pd.DataFrame({"Countries":gpe_list})
# Concatenate with the dataframe 
df_new = pd.concat([df, gpe_df], axis = 1)
#df_new.to_pickle('csv/pickled_df.pkl')

# %%
df_new.drop(columns = ['text', 'date_saved', 'ner']).to_csv("csv/processed10wikipeaks.csv", sep = "~", index = False)

# %%
test1 = []

for x in news_filtered['txt_clean_lem']:
    items = x.split(' ')
    test1.append(items)
    
txt_words = pd.DataFrame({"txt_lems":test1})
t = pd.concat([news_filtered, txt_words], axis = 1)
t.head()
# Out:
#                  common_name      scientific_name  \
# 0   Square-lipped Rhinoceros  Ceratotherium simum
# 1                 Amur Tiger      Panthera tigris
# 2                Indian Lion         Panthera leo
# 3           White Rhinoceros  Ceratotherium simum
# 4               Asiatic Lion         Panthera leo
#
#                                         distribution      iucn_status  \
# 0  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 1  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...               EN
# 2  Afghanistan, Algeria, Angola, Benin, Botswana,...               VU
# 3  Angola, Botswana, Central African Republic, Ch...  Near Threatened
# 4  Afghanistan, Algeria, Angola, Benin, Botswana,...               VU
#
#    date_saved                                               text  \
# 0  2020-06-18  Three female white rhinoceros escaped a safari...
# 1  2020-06-18  For the first time, conservationists have spot...
# 2  2020-06-18  New Delhi: In his Independence Day speech last...
# 3  2020-06-18  With rhino numbers collapsed due to poaching f...
# 4  2020-06-18  Census finds 27% increase in number of endange...
#
#                                                title  \
# 0   Israeli rhino named Rihanna escapes local safari
# 1            Photo First: Rare Tiger Family Portrait
# 2    Does Narendra Modi like lions more than tigers?
# 3  At home with the world's last male northern wh...
# 4             India's Asiatic lion population rising
#
#                                                 link  \
# 0  https://news.google.com/articles/CBMiOmh0dHBzO...
# 1  https://news.google.com/articles/CBMiQWh0dHBzO...
# 2  https://news.google.com/articles/CBMiY2h0dHBzO...
# 3  https://news.google.com/articles/CBMidGh0dHBzO...
# 4  https://news.google.com/articles/CBMiWWh0dHBzO...
#
#                                                image       date  \
# 0  https://www.ynetnews.com/PicServer3/2013/01/01... 2015-01-01
# 1  https://cdn.mos.cms.futurecdn.net/GiUhM5vndrft... 2015-03-10
# 2  https://images.livemint.com/rf/Image-621x414/L... 2015-04-24
# 3  https://i.guim.co.uk/img/media/5ee08ab5a77c5e9... 2015-04-27
# 4  https://i.guim.co.uk/img/static/sys-images/Gua... 2015-05-11
#
#                                                  ner  \
# 0  [{'sent': 'Three female white rhinoceros escap...
# 1  [{'sent': "For the first time, conservationist...
# 2  [{'sent': 'New Delhi: In his Independence Day ...
# 3  [{'sent': 'With rhino numbers collapsed due to...
# 4  [{'sent': 'Census finds 27% increase in number...
#
#                                                  url  shares  reactions  \
# 0  https://www.ynetnews.com/articles/0,7340,L-461...     0.0        0.0
# 1  https://www.livescience.com/50093-amur-tiger-f...     0.0        0.0
# 2  https://www.livemint.com/Politics/ZpXwvuIML2vM...     0.0        0.0
# 3  https://www.theguardian.com/environment/2015/a...   389.0     2865.0
# 4  https://www.theguardian.com/environment/2015/m...   248.0     1754.0
#
#    comments                                      txt_clean_lem  \
# 0       0.0  three female white rhinoceros escaped safari c...
# 1       0.0  first conservationist spotted amur dad leading...
# 2       0.0  new delhi independence speech last year prime ...
# 3     440.0  number collapsed due poaching horn lot ride pa...
# 4      88.0  census find  increase number endangered lion f...
#
#                                             txt_lems
# 0  [three, female, white, rhinoceros, escaped, sa...
# 1  [first, conservationist, spotted, amur, dad, l...
# 2  [new, delhi, independence, speech, last, year,...
# 3  [number, collapsed, due, poaching, horn, lot, ...
# 4  [census, find, , increase, number, endangered,...

# %%
t.to_excel("csv/processedtxt_10wiki.xlsx", engine='xlsxwriter')

# %%
t.to_csv("csv/articles_10peaks_wiki.csv", sep = "/", index = False)

# %%
# Saving top 500 words to create topics out of 
t.explode('txt_lems')['txt_lems'].value_counts().nlargest(1000)
#title_wrds.to_csv("txt_lems.csv")
# Out:
#             5449
# zoo          762
# year         491
# wildlife     485
# lion         470
#             ...
# tag           23
# mount         23
# gave          23
# savanna       23
# join          23
# Name: txt_lems, Length: 1000, dtype: int64

# %%
txt

# %%
# Explode the lists in the Countries column so each species has one row dedicated per country
s = df_new.explode('Countries').groupby(['scientific_name'])['Countries'].value_counts()

# %%
# create csv
s.to_csv("csv/Countries_byspecies_count.csv", sep = ';')

# %%
# Explode the lists in the Countries column so each species has one row dedicated per country
#s = df_new.explode('Countries').groupby(['scientific_name'])['Countries'].value_counts()
# create csv
#s.to_csv("Countries_inarticles_count.csv", sep = ';')

# read in newly created dataframe 
country_count = pd.read_csv("csv/Countries_byspecies_count.csv", sep = ';')
# read in relevant datafile
x = pd.read_csv("csv/speciesinfo.csv", sep = ";")

country_count = country_count.rename(columns = {'Countries.1' : 'mentions_country'})

country_count = country_count.merge(x, on = 'scientific_name', how = 'inner')

# Save to csv for geocoding in other notebook
country_count.to_csv("speciesinfo_gpetags.csv", sep = ';', index = False)

# %%
def list_to_graph(name):

    # Set up the placeholder list
    final_list = []

    # Loop over each list in the list of lists
    for nlist in name:
    
        # Extend the final list with the current list
        final_list.extend(nlist)
    
    # Convert the list into a pandas Series, count unique nouns
    # using the value_counts() method, get the 10 most frequent
    # items [:10] and plot the result into a bar chart using the
    # plot() method and its attribute 'kind'.
    return pd.Series(final_list).value_counts()[:15].plot(kind='bar')

# %% [markdown]
# ### Sentiment analysis

# %%
# Read in the processed dataframe
alltext = pd.read_csv("articles_no_engagement.csv", sep = ";")
len(alltext)
# Out:
# 13066

# %%
# import SentimentIntensityAnalyzer class
# from vaderSentiment.vaderSentiment module.
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# function to print sentiments
# of the sentence.
def sentiment_scores(sentence):

	# Create a SentimentIntensityAnalyzer object.
	sid_obj = SentimentIntensityAnalyzer()

	# polarity_scores method of SentimentIntensityAnalyzer
	# object gives a sentiment dictionary.
	# which contains pos, neg, neu, and compound scores.
	sentiment_dict = sid_obj.polarity_scores(sentence)

	# decide sentiment as positive, negative and neutral
	if sentiment_dict['compound'] >= 0.05 :
		return("Positive")

	elif sentiment_dict['compound'] <= - 0.05 :
		return("Negative")

	else :
		return("Neutral")



scores = []
# Driver code
if __name__ == "__main__" :
    
    for text in alltext['text']:

        #print("Article text:", text)
	# function calling
        score = sentiment_scores(text)
        scores.append(score)
        
len(scores)
# Out:
# 13066

# %%
alltext = pd.concat([alltext, pd.DataFrame({'sentiment': scores})], axis = 1)

# %%
alltext['sentiment'].value_counts()
# Out:
# Positive    9162
# Negative    3726
# Neutral      178
# Name: sentiment, dtype: int64

# %%
alltext.to_csv("alltext-no-engagement-sentimet.csv", sep = ";", index = False)

# %% [markdown]
# ### Keep in case of loss of processed text CSV

# %%
# read in the dataset 
df = pd.read_json('animal_news_database.json', lines = True)
# Read in the datasets defining our subset data

charismatic = pd.read_csv("csv/charismatic_16.csv", sep = ";")
charismatic = charismatic.rename(columns = {'Scientifc Name' : 'scientific_name'})

# Drop Twitter handles as they are not species names
df = df[df.scientific_name.str.contains('@') == False]
df.reset_index(drop = True, inplace = True)

# Add new column for storing the values article amount found under each species type 
df['article_amt'] = df['articles'].str.len()
# What is the total amount of articles before any processing
print("Before any processing, the amount of articles in the datset:", df['article_amt'].sum())

# Read in the CITES data to join with the main dataframe
cites1 = pd.read_csv("csv/cites1.csv", delimiter = ';')

# Keep only most relevant columns
cites1 = cites1[['Kingdom', 'Class', 'Order', 'Family', 'Genus', 'Species', 'Scientific Name', 'Listing', 'NativeDistributionFullNames', 'Extinct_Distribution']]

cites1 = cites1.rename(columns = {'Scientific Name' : 'scientific_name'})

# Do the same for the entire dataframe
df = df.merge(cites1, on = 'scientific_name', how = 'inner')


#df.head()
df = df.drop(['_id'], axis=1)
# Out:
# Before any processing, the amount of articles in the datset: 13565

# %%
# Any changes after merging with CITES data
print("The amount of articles in the datset:", df['article_amt'].sum())
print("The number of species in the dataset:", df['scientific_name'].nunique())
# Out:
# The amount of articles in the datset: 13855
# The number of species in the dataset: 584

# %%
#### Unneccessary as defining charisma hasn't been really realized as an option


df['Charisma'] = 0

# Loop through the species and create a binary classification for species that are charismatic or not
for x in df['scientific_name']:
    if x in list(charismatic['scientific_name']):
        df.loc[df['scientific_name'] == x, 'Charisma'] = 1

# %%
# Explode the articles column
s = df['articles'].map(dict.values).explode()
# NaN values need to be droppped
s = s.dropna()
# Drop the column articles and join the exploded values to the dataframe
df_full = df.drop(columns=['articles']).join(pd.DataFrame([*s], s.index))

# %%
uniquelinks = pd.DataFrame(df_full['link'].unique()).dropna().reset_index(drop=True)
uniquelinks.to_csv("csv/uniquelinks.csv", sep = ";", index = False)

# %%
# Processing for articles       
# keep only unique article instances
df_media = df_full.drop_duplicates(subset=['text'])
# Transform date column into DateTime
df_media["date"] = df_media["date"].apply(pd.to_datetime)
# Sort by oldest to newest
df_media = df_media.sort_values(by="date")
# Drop article amt column, unneccessary 
#df_media = df_media.drop(columns=['article_amt'])
# reset index
df_media.reset_index(drop = True, inplace = True)
# Remove any rows with blank data for the text column
df_media = df_media[df_media['text'].notna()]
# Out:
# /tmp/ipykernel_80/3856464177.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_media["date"] = df_media["date"].apply(pd.to_datetime)

# %% [markdown]
# ### Topics

# %%
# Import Charismatic species dataset and the codebook
rz = pd.read_csv("csv/rz_media.csv", sep = ";")
rz
# Out:
#               common_name        scientific_name  \
# 0        Javan Rhinoceros   Rhinoceros sondaicus
# 1        Javan Rhinoceros   Rhinoceros sondaicus
# 2           Grevy's Zebra           Equus grevyi
# 3                  Tucuxi    Sotalia fluviatilis
# 4         Western Gorilla        Gorilla gorilla
# ...                   ...                    ...
# 2844    Irrawaddy Dolphin  Orcaella brevirostris
# 2845            Fin Whale  Balaenoptera physalus
# 2846    Irrawaddy Dolphin  Orcaella brevirostris
# 2847              Panther        Panthera pardus
# 2848  Estuarine Crocodile     Crocodylus porosus
#
#                                            distribution  \
# 0     Bangladesh, Cambodia, China, India, Indonesia,...
# 1     Bangladesh, Cambodia, China, India, Indonesia,...
# 2       Djibouti, Ethiopia, Kenya, Somalia, South Sudan
# 3     Brazil, Colombia, Costa Rica, Ecuador, Nicarag...
# 4     Angola, Cameroon, Central African Republic, Co...
# ...                                                 ...
# 2844  Australia, Bangladesh, Brunei Darussalam, Camb...
# 2845  Algeria, Angola, Antarctica, Argentina, Austra...
# 2846  Australia, Bangladesh, Brunei Darussalam, Camb...
# 2847  Afghanistan, Algeria, Angola, Armenia, Azerbai...
# 2848  Australia, Bangladesh, Brunei Darussalam, Camb...
#
#                    iucn_status  date_saved   Kingdom   Class_x  \
# 0        Critically Endangered  2020-06-18  Animalia  Mammalia
# 1        Critically Endangered  2020-06-18  Animalia  Mammalia
# 2                           EN  2020-06-18  Animalia  Mammalia
# 3               Data Deficient  2020-06-18  Animalia  Mammalia
# 4                           CR  2020-06-18  Animalia  Mammalia
# ...                        ...         ...       ...       ...
# 2844                        EN  2020-06-18  Animalia  Mammalia
# 2845                        VU  2020-06-18  Animalia  Mammalia
# 2846                        EN  2020-06-18  Animalia  Mammalia
# 2847                        VU  2020-06-18  Animalia  Mammalia
# 2848  Lower Risk/least concern  2020-06-18  Animalia  Reptilia
#
#                Order           Family         Genus  ...  \
# 0     Perissodactyla   Rhinocerotidae    Rhinoceros  ...
# 1     Perissodactyla   Rhinocerotidae    Rhinoceros  ...
# 2     Perissodactyla          Equidae         Equus  ...
# 3            Cetacea      Delphinidae       Sotalia  ...
# 4           Primates        Hominidae       Gorilla  ...
# ...              ...              ...           ...  ...
# 2844         Cetacea      Delphinidae      Orcaella  ...
# 2845         Cetacea  Balaenopteridae  Balaenoptera  ...
# 2846         Cetacea      Delphinidae      Orcaella  ...
# 2847       Carnivora          Felidae      Panthera  ...
# 2848      Crocodylia     Crocodylidae    Crocodylus  ...
#
#                                                   image        date  \
# 0     https://statik.tempo.co/data/2015/02/09/id_369...  1970-01-01
# 1     https://statik.tempo.co/data/2011/12/29/id_100...  1970-01-01
# 2     https://i1.wp.com/www.horsetalk.co.nz/wp-conte...  2001-11-30
# 3     https://i.guim.co.uk/img/static/sys-images/Env...  2003-07-03
# 4     http://newsimg.bbc.co.uk/media/images/39953000...  2004-03-23
# ...                                                 ...         ...
# 2844  https://www.thecanary.co/wp-content/uploads/20...  2020-05-30
# 2845  https://www.scubadivermag.com/wp-content/uploa...  2020-05-30
# 2846  https://www.deccanherald.com/sites/dh/files/ar...  2020-05-31
# 2847  https://usatlonzowire.files.wordpress.com/2020...  2020-05-31
# 2848  https://www.hindustantimes.com/rf/image_size_9...  2020-12-30
#
#                                                     ner  \
# 0     [{'sent': 'TEMPO.CO, Jakarta - Indonesia is ho...
# 1     [{'sent': 'TEMPO.CO, Jakarta - Director of the...
# 2     [{'sent': 'A Grevy’s', 'ents': {'ORG': ['Grevy...
# 3     [{'sent': 'At the Institute for Marine Mammal ...
# 4     [{'sent': 'By Helen Briggs\n\n', 'ents': {'PER...
# ...                                                 ...
# 2844  [{'sent': '(CBTH) founder Eduardo Gonçalves ha...
# 2845  [{'sent': 'A 12-metre-long fin whale which was...
# 2846  [{'sent': 'In a unique initiative, researchers...
# 2847  [{'sent': 'Lonzo Ball is never one to shy away...
# 2848  [{'sent': 'india\n\n', 'ents': {'GPE': ['india...
#
#                                           processed_txt  \
# 0     TEMPO.CO, Jakarta - Indonesia is home to two o...
# 1     TEMPO.CO, Jakarta - Director of the Biodiversi...
# 2     Share\n\n\n\n\n\n\n\n\n\n\n\nA Grevy’s Zebra f...
# 3     At the Institute for Marine Mammal Studies in ...
# 4     By Helen Briggs\n\nBBC News Online science rep...
# ...                                                 ...
# 2844  The Campaign to Ban Trophy Hunting’s (CBTH) fo...
# 2845  A 12-metre-long fin whale which washed up at H...
# 2846  In a unique initiative, researchers from the I...
# 2847  Lonzo Ball is never one to shy away from an op...
# 2848  india\n\nUpdated: Dec 30, 2019 23:09 IST\n\nTh...
#
#                                         text_clean_spcy  \
# 0     tempoco jakarta indonesia home two five rhinoc...
# 1     tempoco jakarta director biodiversity conserva...
# 2     sharea grevy ’s zebra foal bear live desert zo...
# 3     institute marine mammal study mississippi kell...
# 4     helen briggsbbc news online science reporterwe...
# ...                                                 ...
# 2844  campaign ban trophy hunting ’s cbth founder ed...
# 2845    fin whale wash hollandonsea essex friday mor...
# 2846  unique initiative researcher indian institute ...
# 2847  lonzo ball never one shy away opportunity call...
# 2848  indiaupdate dec     istthe sunderbans world ’s...
#
#                                                     GPE  \
# 0     ['TEMPO.CO', 'Jakarta', 'Indonesia', 'West Jav...
# 1       ['TEMPO.CO', 'Jakarta', 'West Java', 'Cikepuh']
# 2     ['Palm Desert', 'California', 'Natalia', 'Conr...
# 3     ['Mississippi', 'EQ', 'EQ', 'EQ', 'Brazil', 'M...
# 4     ['Central African Republic', 'the Democratic R...
# ...                                                 ...
# 2844  ['Gonçalves', 'US', 'Gonçalves', 'UK', 'UK', '...
# 2845                                        ['Holland']
# 2846  ['Odisha', 'India', 'Odisha', 'Chilika', 'Chil...
# 2847                   ['New Orleans', 'Black Panther']
# 2848  ['india', 'Delhi', 'West Bengal', 'India', 'Ba...
#
#                                                     LOC  \
# 0                                             ['earth']
# 1                                                    []
# 2                                 ['The Living Desert']
# 3                                           ['Straits']
# 4                                       ['Cross River']
# ...                                                 ...
# 2844                                  ['Mediterranean']
# 2845                                                 []
# 2846  ['Asia', 'Puri', 'Mahanadi river', 'South', 'N...
# 2847                                                 []
# 2848         ['the Bay of Bengal', 'the Bay of Bengal']
#
#                                                     ORG  \
# 0     ['the Environment and Forestry Ministry', 'the...
# 1     ['the Ministry of Environment and Forestry', '...
# 2     ['Grevy', 'the Species Survival Plan', '• Hous...
# 3     ['the Institute for Marine Mammal Studies', 'K...
# 4     ['BBC News Online', 'the Mondika Research Stat...
# ...                                                 ...
# 2844  ['The Campaign to Ban Trophy Hunting’s', 'CBTH...
# 2845  ['the Institute of Zoology', 'Tendring Distric...
# 2846  ['the Indian Institute of Technology Madras', ...
# 2847  ['Instagram', 'Jrue Holiday to Captain America...
# 2848  ['delta', 'the Royal Bengal Tiger', 'the Fores...
#
#                                         title_clean_lem  \
# 0                    sumatran rhino population critical
# 1      javan rhino transferred cikepuh wildlife reserve
# 2        california zoo welcome grevy’s zebra colt foal
# 3                                  dolphin deep thinker
# 4                        gorilla study give social clue
# ...                                                 ...
# 2844  new book could final nail coffin trophy huntin...
# 2845               fin whale washed essex beach removed
# 2846  iit researcher help chilika lake odisha triple...
# 2847  lonzo ball jokingly compare jj redick jrue hol...
# 2848  sunderbans lost  mangrove cover two year repor...
#
#                                            topics
# 0                                      ['STATUS']
# 1     ['WILD POPULATIONS', 'CAPTIVE POPULATIONS']
# 2                         ['CAPTIVE POPULATIONS']
# 3                                              []
# 4                                     ['EXPERTS']
# ...                                           ...
# 2844                         ['TRADE', 'HUNTING']
# 2845                                           []
# 2846  ['HUMAN INTERVENTION', 'EXPERTS', 'STATUS']
# 2847                                           []
# 2848                                  ['EXPERTS']
#
# [2849 rows x 34 columns]

# %%
# How many uncategorized articles in dataset with current categorization system
print(len(rz.loc[rz['topics'].isin(['[]'])]))


len(rz)
# Out:
# 1171
# 2849

# %%
# Import Charismatic species dataset and the codebook
#rz = pd.read_csv("csv/rz_media.csv", sep = ";")
#rz = rz.drop(columns = 'Unnamed: 0')

codes = pd.read_csv("csv/codebook_trial1.csv", sep = ";")

# %%
codes
# Out:
#                   topic                                           KEYWORDS  \
# 0   CAPTIVE POPULATIONS  [zoo, park, sanctuary, reserve, farm, released...
# 1          CONSERVATION  [conservation, protect, effort, protection, co...
# 2               DISEASE  [coronavirus, lockdown, viral, dna, pandemic, ...
# 3            ECOTOURISM                                  [safari, tourist]
# 4               EXPERTS  [scientist, study, expert, researcher, report,...
# 5    HUMAN INTERVENTION  [rescued, help, caught, rescue, police, arrest...
# 6               HUNTING  [killed, poached, hunt, fishing, hunting, hunt...
# 7             POLLUTION                         [plastic, net, oil, spill]
# 8                STATUS  [endangered, rare, population, extinction, dea...
# 9                 TRADE               [trade, illegal, pet, trophy, ivory]
# 10             VIOLENCE             [attack, fight, killing, carcass, war]
# 11     WILD POPULATIONS  [wildlife, spotted, sighting, habitat, nature,...
#
#                                                 words
# 0   [zoo, park, sanctuary, reserve, farm, released...
# 1   [conservation, protect, effort, protection, co...
# 2   [coronavirus, lockdown, viral, dna, pandemic, ...
# 3                                   [safari, tourist]
# 4   [scientist, study, expert, researcher, report,...
# 5   [rescued, help, caught, rescue, police, arrest...
# 6   [killed, poached, hunt, fishing, hunting, hunt...
# 7                          [plastic, net, oil, spill]
# 8   [endangered, rare, population, extinction, dea...
# 9                [trade, illegal, pet, trophy, ivory]
# 10             [attack, fight, killing, carcass, war]
# 11  [wildlife, spotted, sighting, habitat, nature,...

# %%
test = []
# Turn the strings into lists
for s in codes['KEYWORDS']:
    s = s.replace('[', '')
    s = s.replace(']', '')
    s = s.replace(',', '')
    test.append(s.split())

# Add as a new column to original df
codes = pd.concat([codes, pd.DataFrame({'words':test})], axis = 1)
# Create a dictionary of the topics and corresponding keywords
topics = dict(zip(codes.topic, codes.words))

# %%
# pip install nltk
import nltk
import re
import string
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer


nltk.download('stopwords')
nltk.download('wordnet')
#Function retrieved from https://www.dataknowsall.com/textcleaning.html

def clean_string(text, stem="None"):

    final_string = ""

    # Make lower
    text = text.lower()

    # Remove line breaks
    text = re.sub(r'\n', '', text)

    # Remove puncuation
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    # Remove stop words
    text = text.split()
    useless_words = nltk.corpus.stopwords.words("english")
    useless_words = useless_words + ['also', 'said', 'would', 'could', 'should', 'told', 'say', 'like', 'u', 
                                     'see', 'day', 'since', 'red', 'often', 'one', 'two', 'time']

    text_filtered = [word for word in text if not word in useless_words]

    # Remove numbers
    text_filtered = [re.sub(r'\w*\d\w*', '', w) for w in text_filtered]

    # Stem or Lemmatize
    if stem == 'Stem':
        stemmer = PorterStemmer() 
        text_stemmed = [stemmer.stem(y) for y in text_filtered]
    elif stem == 'Lem':
        lem = WordNetLemmatizer()
        text_stemmed = [lem.lemmatize(y) for y in text_filtered]
    elif stem == 'Spacy':
        text_filtered = nlp(' '.join(text_filtered))
        text_stemmed = [y.lemma_ for y in text_filtered]
    else:
        text_stemmed = text_filtered

    final_string = ' '.join(text_stemmed)

    return final_string
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Apply the function to the title column as save as new column
df_media['txt_clean_lem'] = df_media['text'].apply(lambda x: clean_string(x, stem='Lem'))

test1 = []
# Turn into lists
for x in df_media['txt_clean_lem']:
    items = x.split(' ')
    test1.append(items)

# Append as a new column, save into new df
key_words = pd.DataFrame({"txt_lems":test1})
t = pd.concat([df_media, key_words], axis = 1)

# %%
# Saving top 500 words to create topics out of 
text_simplified = t.explode('title_lems')['title_lems'].value_counts().nlargest(1000)
text_simplified.to_csv("csv/text_lems.csv")

# %%
docsbyCategory = {}

for i, words in rz['title_clean_lem'].items():
    cats = set()
    word = words.split()
    for category, keywords in topics.items():
        if any(keyword in word for keyword in keywords):
            cats.add(category)
    docsbyCategory[i] = list(cats)
    
print(docsbyCategory)
# Out:
# {0: ['STATUS'], 1: ['WILD POPULATIONS', 'CAPTIVE POPULATIONS'], 2: ['CAPTIVE POPULATIONS'], 3: [], 4: ['EXPERTS'], 5: [], 6: ['TRADE', 'HUNTING'], 7: [], 8: ['STATUS'], 9: ['STATUS'], 10: [], 11: ['STATUS'], 12: [], 13: [], 14: ['STATUS'], 15: ['STATUS'], 16: ['STATUS'], 17: ['STATUS'], 18: ['STATUS'], 19: ['WILD POPULATIONS', 'TRADE'], 20: ['STATUS'], 21: ['HUNTING'], 22: ['WILD POPULATIONS'], 23: [], 24: [], 25: ['HUMAN INTERVENTION'], 26: [], 27: ['CONSERVATION'], 28: ['HUNTING'], 29: ['DISEASE', 'EXPERTS', 'HUNTING'], 30: ['HUNTING'], 31: [], 32: [], 33: ['STATUS'], 34: ['EXPERTS'], 35: [], 36: [], 37: [], 38: [], 39: ['VIOLENCE', 'CAPTIVE POPULATIONS', 'STATUS'], 40: [], 41: [], 42: ['WILD POPULATIONS'], 43: [], 44: [], 45: ['STATUS'], 46: [], 47: [], 48: [], 49: ['STATUS'], 50: ['CAPTIVE POPULATIONS'], 51: ['HUNTING'], 52: ['STATUS'], 53: ['STATUS'], 54: ['CAPTIVE POPULATIONS'], 55: ['CAPTIVE POPULATIONS'], 56: ['ECOTOURISM', 'CAPTIVE POPULATIONS'], 57: [], 58: [], 59: ['HUNTING', 'STATUS'], 60: [], 61: [], 62: ['STATUS'], 63: ['HUNTING', 'STATUS'], 64: ['EXPERTS'], 65: [], 66: [], 67: [], 68: [], 69: ['CONSERVATION'], 70: ['CAPTIVE POPULATIONS'], 71: [], 72: [], 73: ['STATUS'], 74: ['STATUS'], 75: ['VIOLENCE'], 76: ['WILD POPULATIONS'], 77: ['CAPTIVE POPULATIONS'], 78: ['HUMAN INTERVENTION', 'HUNTING'], 79: ['CONSERVATION'], 80: [], 81: [], 82: [], 83: [], 84: ['CAPTIVE POPULATIONS'], 85: [], 86: [], 87: ['HUMAN INTERVENTION'], 88: [], 89: [], 90: ['STATUS'], 91: [], 92: ['CAPTIVE POPULATIONS'], 93: ['HUMAN INTERVENTION'], 94: ['STATUS'], 95: [], 96: [], 97: [], 98: ['WILD POPULATIONS'], 99: [], 100: [], 101: ['EX
rz = pd.concat([rz, pd.DataFrame({"topics":docsbyCategory})], axis = 1)

# %%
rz.to_csv('csv/rz_media.csv', sep = ';', index = False)

# %%
test = rz.explode('topics')

# %%
test.columns
# Out:
# Index(['common_name', 'scientific_name', 'distribution', 'iucn_status',
#        'date_saved', 'Kingdom', 'Class_x', 'Order', 'Family', 'Genus',
#        'Species', 'Listing', 'NativeDistributionFullNames',
#        'Extinct_Distribution', 'Common name', 'General ID name', 'Count',
#        'Class_y', 'Ecosystem', 'Appendix', 'Appendix exceptions, if any',
#        'text', 'title', 'link', 'image', 'date', 'ner', 'processed_txt',
#        'text_clean_spcy', 'GPE', 'LOC', 'ORG', 'title_clean_lem', 'topics'],
#       dtype='object')

# %%
#test['COUNTER'] =1 
test.groupby(['topics','scientific_name', 'title'])['COUNTER'].sum()
# Out:
# topics               scientific_name   title
# CAPTIVE POPULATIONS  Acinonyx jubatus  Best Friends With A Purpose: Cheetah Has A Therapy Dog At The Turtle Back Zoo                          1
#                                        Bringing the Zoo to You: April 2020 Edition                                                            1
#                                        Colchester Zoo's cheetah Sia successfully gives birth to five cubs                                     1
#                                        Columbus Zoo announces first baby cheetah cubs born via IVF                                            1
#                                        Elusive Siberian tigers captured in spectacular photos                                                 1
#                                                                                                                                              ..
# WILD POPULATIONS     Ursus thibetanus  Nature Revives During Lockdown But Wild Animals Attacking People Too                                   1
#                                        Rare Asiatic black bear spotted out for a walk in the Korean Demilitarised Zone                        1
#                                        The week in wildlife – in pictures                                                                     1
#                                        Uttarakhand Forest Dept seizes three bear gall bladders; activists say poaching of bear on the rise    1
#                                        Villagers rescue bear cubs from Sendenyu forest in Nagaland                                            1
# Name: COUNTER, Length: 2313, dtype: int64

# %%
#test['COUNTER'] =1       #initially, set that counter to 1.
group_data = test.groupby(['topics','scientific_name', 'title'])['COUNTER'].sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


ax = sns.barplot(
    x = 'topics',
    y = 'article_count',
    data = ser_df, 
    width = 0.7, palette = 'rocket', dodge = False
)
ax.set_xlabel('Category', fontsize=9)
ax.set_ylabel('Article Count', fontsize=9)

# Add suptitle above the title
plt.suptitle("Topic Popularity in Dataset\n", fontsize=16)

# Add title
#ax.title("Realized by the Python Graph Gallery", color="grey", style='italic')
ax.set_title('News articles collected in April 2020', fontsize = 10, color="grey", style='italic')


ax.tick_params(axis='x', rotation=85, length = 9, labelsize = 7, left = True)
#ax.legend()#bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0
#plt.savefig('figures/topic_popularity.png', bbox_inches = 'tight')

# %%
ser = rz.explode('topics')['topics'].value_counts()

# %%
ser_df = pd.DataFrame(ser).reset_index()
ser_df.columns = ['topics', 'article_count']
ser_df
# Out:
#                  topics  article_count
# 0                STATUS            572
# 1   CAPTIVE POPULATIONS            468
# 2      WILD POPULATIONS            286
# 3               HUNTING            187
# 4    HUMAN INTERVENTION            184
# 5               EXPERTS            170
# 6          CONSERVATION            141
# 7               DISEASE            100
# 8              VIOLENCE             77
# 9                 TRADE             66
# 10           ECOTOURISM             54
# 11            POLLUTION             23
