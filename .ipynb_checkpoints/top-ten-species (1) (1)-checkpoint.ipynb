# %%
import pandas as pd
import geopandas as gpd
import json
from ast import literal_eval
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in the dataset 
df = pd.read_json('animal_news_database.json', lines = True)
df
# Out:
#                                        _id                   common_name  \
# 0     {'$oid': '5eb530eeccc46a6a739577a2'}   Campbell's alligator lizard
# 1     {'$oid': '5eb53116ccc46a6a739577a6'}   Southern plains gray langur
# 2     {'$oid': '5eb53156ccc46a6a739577ab'}             Natal giant cycad
# 3     {'$oid': '5eb53162ccc46a6a739577ad'}         Bengal hanuman langur
# 4     {'$oid': '5eb53171ccc46a6a739577af'}            Mongolian Wild Ass
# ...                                    ...                           ...
# 2272  {'$oid': '5ed349928089be8ca72beb86'}                    Chimpanzee
# 2273  {'$oid': '5ed34a668089be8ca72beb87'}             Common chimpanzee
# 2274  {'$oid': '5ed352f08089be8ca72beb8a'}              @TRAFFIC_WLTrade
# 2275  {'$oid': '5ed355ec8089be8ca72beb8b'}                  @IlWildTrade
# 2276  {'$oid': '5ed35b528089be8ca72beb8c'}                  @WLTradeNews
#
#                scientific_name  \
# 0            Abronia campbelli
# 1     Semnopithecus dussumieri
# 2     Encephalartos natalensis
# 3       Semnopithecus entellus
# 4      Equus hemionus hemionus
# ...                        ...
# 2272           Pan troglodytes
# 2273           Pan troglodytes
# 2274          @TRAFFIC_WLTrade
# 2275              @IlWildTrade
# 2276              @WLTradeNews
#
#                                            distribution  \
# 0                                             Guatemala
# 1                                                 India
# 2                                          South Africa
# 3                    Bangladesh, India, Nepal, Pakistan
# 4       China, Kazakhstan, Mongolia, Russian Federation
# ...                                                 ...
# 2272  Angola, Benin, Burkina Faso, Burundi, Cameroon...
# 2273  Angola, Benin, Burkina Faso, Burundi, Cameroon...
# 2274                                                 NA
# 2275                                                 NA
# 2276                                                 NA
#
#                 iucn_status  \
# 0     Critically Endangered
# 1             Least Concern
# 2           Near Threatened
# 3             Least Concern
# 4                        NA
# ...                     ...
# 2272                     EN
# 2273                     EN
# 2274                     NA
# 2275                     NA
# 2276                     NA
#
#                                                articles  date_saved
# 0     {'0': {'text': 'A 3-foot-long (1 meter) green ...  2020-06-18
# 1     {'3': {'text': 'On Thursday, a Nilgai was foun...  2020-06-18
# 2     {'0': {'text': 'A GUIDED walk entitled Interes...  2020-06-18
# 3     {'1': {'text': 'Advertisement
#
# From the tropic...  2020-06-18
# 4     {'0': {'text': 'Exploding demand for cashmere ...  2020-06-18
# ...                                                 ...         ...
# 2272  {'0': {'text': 'The Chimpanzee Sanctuary & Wil...  2020-06-18
# 2273                                                 {}  2020-06-18
# 2274  {'0': {'text': 'Pangolins are trafficked for t...  2020-06-18
# 2275  {'0': {'text': 'india
#
# Updated: May 03, 2016 1...  2020-06-18
# 2276  {'0': {'text': 'This evening, Prince William a...  2020-06-18
#
# [2277 rows x 7 columns]

# %%
# How many species listed total in this dataset
df['scientific_name'].nunique()
# Out:
# 585

# %%
# Drop Twitter handles as they are not species names
df = df[df.scientific_name.str.contains('@') == False]
df.reset_index(drop = True, inplace = True)

# %%
# Add new column for storing the values article amount found under each species type 

for i, row in df.iterrows():
    df.at[i, 'article_amt'] = len(row.articles.values())
# Out:
# /tmp/ipykernel_93/3674604320.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.at[i, 'article_amt'] = len(row.articles.values())

# %%
df
# Out:
#                                        _id                   common_name  \
# 0     {'$oid': '5eb530eeccc46a6a739577a2'}   Campbell's alligator lizard
# 1     {'$oid': '5eb53116ccc46a6a739577a6'}   Southern plains gray langur
# 2     {'$oid': '5eb53156ccc46a6a739577ab'}             Natal giant cycad
# 3     {'$oid': '5eb53162ccc46a6a739577ad'}         Bengal hanuman langur
# 4     {'$oid': '5eb53171ccc46a6a739577af'}            Mongolian Wild Ass
# ...                                    ...                           ...
# 2265  {'$oid': '5ed346f48089be8ca72beb7c'}                         Chiru
# 2266  {'$oid': '5ed347c88089be8ca72beb80'}               Himalayan Monal
# 2267  {'$oid': '5ed348de8089be8ca72beb85'}                 Chinese Monal
# 2268  {'$oid': '5ed349928089be8ca72beb86'}                    Chimpanzee
# 2269  {'$oid': '5ed34a668089be8ca72beb87'}             Common chimpanzee
#
#                scientific_name  \
# 0            Abronia campbelli
# 1     Semnopithecus dussumieri
# 2     Encephalartos natalensis
# 3       Semnopithecus entellus
# 4      Equus hemionus hemionus
# ...                        ...
# 2265      Pantholops hodgsonii
# 2266     Lophophorus impejanus
# 2267       Lophophorus lhuysii
# 2268           Pan troglodytes
# 2269           Pan troglodytes
#
#                                            distribution  \
# 0                                             Guatemala
# 1                                                 India
# 2                                          South Africa
# 3                    Bangladesh, India, Nepal, Pakistan
# 4       China, Kazakhstan, Mongolia, Russian Federation
# ...                                                 ...
# 2265                                China, India, Nepal
# 2266  Afghanistan, Bhutan, China, India, Myanmar, Ne...
# 2267                                              China
# 2268  Angola, Benin, Burkina Faso, Burundi, Cameroon...
# 2269  Angola, Benin, Burkina Faso, Burundi, Cameroon...
#
#                 iucn_status  \
# 0     Critically Endangered
# 1             Least Concern
# 2           Near Threatened
# 3             Least Concern
# 4                        NA
# ...                     ...
# 2265        Near Threatened
# 2266          Least Concern
# 2267                     VU
# 2268                     EN
# 2269                     EN
#
#                                                articles  date_saved  \
# 0     {'0': {'text': 'A 3-foot-long (1 meter) green ...  2020-06-18
# 1     {'3': {'text': 'On Thursday, a Nilgai was foun...  2020-06-18
# 2     {'0': {'text': 'A GUIDED walk entitled Interes...  2020-06-18
# 3     {'1': {'text': 'Advertisement
#
# From the tropic...  2020-06-18
# 4     {'0': {'text': 'Exploding demand for cashmere ...  2020-06-18
# ...                                                 ...         ...
# 2265                                                 {}  2020-06-18
# 2266                                                 {}  2020-06-18
# 2267  {'5': {'text': 'A giant panda was captured by ...  2020-06-18
# 2268  {'0': {'text': 'The Chimpanzee Sanctuary & Wil...  2020-06-18
# 2269                                                 {}  2020-06-18
#
#       article_amt
# 0             2.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             5.0
# ...           ...
# 2265          0.0
# 2266          0.0
# 2267          1.0
# 2268          5.0
# 2269          0.0
#
# [2270 rows x 8 columns]

# %%
## Good syntax to remember to find specific instances of a value in a specific column
#df.loc[df['scientific_name'].isin(['Perameles bougainville'])]
# Out:
#                                        _id                common_name  \
# 57    {'$oid': '5eb542acdbb5c0003a39f6e4'}           Barred Bandicoot
# 67    {'$oid': '5eb5442fdbb5c0003a39f703'}       Long-nosed Bandicoot
# 85    {'$oid': '5eb546fcdbb5c0003a39f737'}                        Mal
# 95    {'$oid': '5eb54878dbb5c0003a39f746'}                       Marl
# 98    {'$oid': '5eb548dedbb5c0003a39f749'}   Western Barred Bandicoot
# 1020  {'$oid': '5ecd3dd929e34476272be152'}           Barred Bandicoot
# 1028  {'$oid': '5ecd3ede29e34476272be16c'}       Long-nosed Bandicoot
# 1044  {'$oid': '5ecd417d29e34476272be1a7'}                        Mal
# 1057  {'$oid': '5ecd42bc29e34476272be1bb'}                       Marl
# 1059  {'$oid': '5ecd42ee29e34476272be1bd'}   Western Barred Bandicoot
# 1845  {'$oid': '5ed2e3478089be8ca72be4ab'}           Barred Bandicoot
# 1851  {'$oid': '5ed2e4a88089be8ca72be4cd'}                        Mal
# 1858  {'$oid': '5ed2e6768089be8ca72be4f9'}                       Marl
#
#              scientific_name distribution iucn_status  \
# 57    Perameles bougainville    Australia          VU
# 67    Perameles bougainville    Australia          VU
# 85    Perameles bougainville    Australia          VU
# 95    Perameles bougainville    Australia          VU
# 98    Perameles bougainville    Australia          VU
# 1020  Perameles bougainville    Australia          VU
# 1028  Perameles bougainville    Australia          VU
# 1044  Perameles bougainville    Australia          VU
# 1057  Perameles bougainville    Australia          VU
# 1059  Perameles bougainville    Australia          VU
# 1845  Perameles bougainville    Australia          VU
# 1851  Perameles bougainville    Australia          VU
# 1858  Perameles bougainville    Australia          VU
#
#                                                articles  date_saved  \
# 57    {'1': {'text': 'Share this
#
# Article Facebook
#
# ...  2020-06-18
# 67    {'3': {'text': 'They aren't quite flying, but ...  2020-06-18
# 85    {'1': {'text': 'Hiya teamâ€¦.and what a cracki...  2020-06-18
# 95    {'14': {'text': 'In total, 77 samples have bee...  2020-06-18
# 98    {'8': {'text': 'If you look up the Bernier and...  2020-06-18
# 1020  {'12': {'text': 'Two men were arrested by Fish...  2020-06-18
# 1028  {'5': {'text': 'Australia has some of the most...  2020-06-18
# 1044  {'35': {'text': 'Biryani, kebabs, sheer mal, k...  2020-06-18
# 1057  {'0': {'text': 'MANTUA TWP. â€” Although they ...  2020-06-18
# 1059  {'11': {'text': 'More than one hundred years s...  2020-06-18
# 1845  {'31': {'text': 'A bandicoot species, which di...  2020-06-18
# 1851                                                 {}  2020-06-18
# 1858  {'19': {'text': 'Sign up to FREE email alerts ...  2020-06-18
#
#       article_amt
# 57           54.0
# 67           18.0
# 85            7.0
# 95            6.0
# 98            5.0
# 1020         11.0
# 1028          3.0
# 1044          3.0
# 1057          4.0
# 1059          1.0
# 1845          1.0
# 1851          0.0
# 1858          2.0

# %%
# Group dataframe by the scientific name that remains consistent for all rows 
grouped = df.groupby('scientific_name')

# Calculate the totals of the group species
article_totals = grouped.article_amt.sum().round()

# %%
# Filter out species with less than 10 articles, not enough data 
article_totals = article_totals[article_totals > 10]

# %%
article_totals.nsmallest(20)
# Out:
# scientific_name
# Balearica pavonina            11.0
# Brachylophus vitiensis        11.0
# Chinchilla lanigera           11.0
# Hippotragus niger variani     11.0
# Lepilemur septentrionalis     11.0
# Mycteria cinerea              11.0
# Rhynchopsitta pachyrhyncha    11.0
# Andrias japonicus             12.0
# Ara macao                     12.0
# Bettongia tropica             12.0
# Ciconia boyciana              12.0
# Cyclura cornuta               12.0
# Fregata andrewsi              12.0
# Macrocephalon maleo           12.0
# Ognorhynchus icterotis        12.0
# Oreonax flavicauda            12.0
# Trichechus senegalensis       12.0
# Cacatua goffiniana            13.0
# Cyclura pinguis               13.0
# Grus vipio                    13.0
# Name: article_amt, dtype: float64

# %%
# What species are being reported on the most? 
# Create a simple bar graph displaying the amt of articles per species 

        
ax = article_totals.nsmallest(20).plot.bar(color = 'green', figsize = (9,7), fontsize = 12)
ax.set_xlabel('Scientific Name', fontsize=16)
ax.set_title('20 Least Common Species According to Media Coverage', fontsize = 20)
ax.tick_params(axis='x', rotation=80, left = True, pad = 2)
#plt.savefig('top_20_species.png', bbox_inches = 'tight')

# %%
(article_totals.nlargest(20).keys())
# Out:
# Index(['Panthera leo', 'Canis lupus', 'Rhinoceros unicornis',
#        'Perameles bougainville', 'Platanista gangetica', 'Puma concolor',
#        'Semnopithecus entellus', 'Gorilla beringei', 'Panthera tigris',
#        'Ursus thibetanus', 'Dermochelys coriacea', 'Leucopsar rothschildi',
#        'Gavialis gangeticus', 'Eschrichtius robustus', 'Panthera pardus',
#        'Pongo pygmaeus', 'Scleropages formosus', 'Crocodylus porosus',
#        'Loxodonta africana', 'Ceratotherium simum'],
#       dtype='object', name='scientific_name')

# %%
# Create a new dataframe with only the top 10 (or 20) most reported on species *
top_twen = df.loc[df['scientific_name'].isin(article_totals.nlargest(20).keys())]

# %%
top_twen
# Out:
#                                        _id                 common_name  \
# 3     {'$oid': '5eb53162ccc46a6a739577ad'}       Bengal hanuman langur
# 18    {'$oid': '5eb533faccc46a6a739577e5'}               Common Langur
# 19    {'$oid': '5eb53408ccc46a6a739577e6'}             Entellus Langur
# 22    {'$oid': '5eb5359accc46a6a7395780a'}            African Elephant
# 30    {'$oid': '5eb5378bccc46a6a73957838'}   African Savannah Elephant
# ...                                    ...                         ...
# 2255  {'$oid': '5ed341ef8089be8ca72beb5f'}                     Panther
# 2256  {'$oid': '5ed342db8089be8ca72beb64'}                  Amur Tiger
# 2257  {'$oid': '5ed3436f8089be8ca72beb68'}              White Starling
# 2258  {'$oid': '5ed343d18089be8ca72beb69'}              Siberian Tiger
# 2259  {'$oid': '5ed3445a8089be8ca72beb6a'}                       Tiger
#
#              scientific_name  \
# 3     Semnopithecus entellus
# 18    Semnopithecus entellus
# 19    Semnopithecus entellus
# 22        Loxodonta africana
# 30        Loxodonta africana
# ...                      ...
# 2255         Panthera pardus
# 2256         Panthera tigris
# 2257   Leucopsar rothschildi
# 2258         Panthera tigris
# 2259         Panthera tigris
#
#                                            distribution    iucn_status  \
# 3                    Bangladesh, India, Nepal, Pakistan  Least Concern
# 18                   Bangladesh, India, Nepal, Pakistan  Least Concern
# 19                   Bangladesh, India, Nepal, Pakistan  Least Concern
# 22    Angola, Benin, Botswana, Burkina Faso, Burundi...     Vulnerable
# 30    Angola, Benin, Botswana, Burkina Faso, Burundi...     Vulnerable
# ...                                                 ...            ...
# 2255  Afghanistan, Algeria, Angola, Armenia, Azerbai...             VU
# 2256  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...             EN
# 2257                                          Indonesia             CR
# 2258  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...             EN
# 2259  Afghanistan, Bangladesh, Bhutan, Cambodia, Chi...             EN
#
#                                                articles  date_saved  \
# 3     {'1': {'text': 'Advertisement
#
# From the tropic...  2020-06-18
# 18    {'1': {'text': 'GPS-locations help first time ...  2020-06-18
# 19    {'0': {'text': 'Great zoo escapes: confessions...  2020-06-18
# 22    {'2': {'text': 'The African elephant is actual...  2020-06-18
# 30    {'10': {'text': 'Manger has been studying slee...  2020-06-18
# ...                                                 ...         ...
# 2255  {'51': {'text': 'The Black Panther Party membe...  2020-06-18
# 2256  {'54': {'text': 'Scott Waller, a graduate stud...  2020-06-18
# 2257  {'3': {'text': 'Sign up to FREE email alerts f...  2020-06-18
# 2258  {'85': {'text': 'LETTER | The plight of human ...  2020-06-18
# 2259  {'6': {'text': 'Special to the Enquirer
#
# Sonoc...  2020-06-18
#
#       article_amt
# 3             1.0
# 18           27.0
# 19            1.0
# 22           33.0
# 30           17.0
# ...           ...
# 2255          4.0
# 2256          2.0
# 2257         17.0
# 2258          1.0
# 2259         11.0
#
# [225 rows x 8 columns]

# %%
bottom_twen = df.loc[df['scientific_name'].isin(article_totals.nsmallest(20).keys())]

# %%
bottom_twen['scientific_name'].unique()
# Out:
# array(['Cacatua goffiniana', 'Macrocephalon maleo', 'Andrias japonicus',
#        'Fregata andrewsi', 'Trichechus senegalensis', 'Ara macao',
#        'Chinchilla lanigera', 'Mycteria cinerea', 'Ciconia boyciana',
#        'Grus vipio', 'Cyclura cornuta', 'Hippotragus niger variani',
#        'Balearica pavonina', 'Cyclura pinguis', 'Ognorhynchus icterotis',
#        'Rhynchopsitta pachyrhyncha', 'Bettongia tropica',
#        'Oreonax flavicauda', 'Brachylophus vitiensis',
#        'Lepilemur septentrionalis'], dtype=object)

# %%
bottom_twen
# Out:
#                                        _id                    common_name  \
# 10    {'$oid': '5eb5328accc46a6a739577c4'}              Goffin's Cockatoo
# 119   {'$oid': '5eb54c6cdbb5c0003a39f773'}                          Maleo
# 330   {'$oid': '5eb5647cdbb5c0003a39f8b8'}      Japanese Giant Salamander
# 331   {'$oid': '5eb56494dbb5c0003a39f8b9'}          Christmas Frigatebird
# 333   {'$oid': '5eb564d8dbb5c0003a39f8bb'}   Christmas Island Frigatebird
# ...                                    ...                            ...
# 2074  {'$oid': '5ed311628089be8ca72be807'}           Oriental White Stork
# 2105  {'$oid': '5ed3186e8089be8ca72be88c'}              White-naped Crane
# 2149  {'$oid': '5ed324978089be8ca72be974'}            Black crowned crane
# 2154  {'$oid': '5ed326378089be8ca72be992'}              Rhinoceros Iguana
# 2182  {'$oid': '5ed32fb78089be8ca72bea50'}               Northern Bettong
#
#           scientific_name                                       distribution  \
# 10     Cacatua goffiniana                         Indonesia, Solomon Islands
# 119   Macrocephalon maleo                                          Indonesia
# 330     Andrias japonicus                          Japan, Russian Federation
# 331      Fregata andrewsi  Australia, Brunei Darussalam, China, Christmas...
# 333      Fregata andrewsi  Australia, Brunei Darussalam, China, Christmas...
# ...                   ...                                                ...
# 2074     Ciconia boyciana  Bangladesh, China, Democratic People's Republi...
# 2105           Grus vipio  China, Democratic People's Republic of Korea, ...
# 2149   Balearica pavonina  Benin, Burkina Faso, Cameroon, Central African...
# 2154      Cyclura cornuta  Dominican Republic, Haiti, United States Minor...
# 2182    Bettongia tropica                                          Australia
#
#      iucn_status                                           articles  \
# 10            NT  {'5': {'text': 'Figaro, a Goffin’s cockatoo (C...
# 119           EN  {'0': {'text': 'IT was 7am when Wahab Tamati w...
# 330           NT  {'14': {'text': 'Exploring Japanese History
#
# O...
# 331           CR  {'0': {'text': 'KIDAPAWAN City – A local envir...
# 333           CR  {'0': {'text': 'Aves Momento Mori 1 of 10
#
# “Av...
# ...          ...                                                ...
# 2074          EN  {'25': {'text': 'It's beginning to snow as my ...
# 2105          NA  {'10': {'text': 'Earlier this year, word sprea...
# 2149          VU  {'23': {'text': 'Construction works on the Cos...
# 2154          EN                                                 {}
# 2182          EN  {'30': {'text': 'Having fielded various indece...
#
#       date_saved  article_amt
# 10    2020-06-18         10.0
# 119   2020-06-18         11.0
# 330   2020-06-18         11.0
# 331   2020-06-18          6.0
# 333   2020-06-18          5.0
# ...          ...          ...
# 2074  2020-06-18          1.0
# 2105  2020-06-18          2.0
# 2149  2020-06-18          1.0
# 2154  2020-06-18          0.0
# 2182  2020-06-18          1.0
#
# [70 rows x 8 columns]

# %%
# create a dataframe of the articles found under each species instance 
# How to bring over the species names that have been "identified" for each article? **

bottom_media = pd.DataFrame()

for i in bottom_twen.articles:
    for x in i.values():
        nd = pd.DataFrame.from_dict(x)
        bottom_media = pd.concat([bottom_media, nd])
        
        
# keep only unique article instances
bottom_media = bottom_media.drop_duplicates(subset=['text'])

# Transform date column into DateTime
bottom_media["date"] = pd.to_datetime(bottom_media["date"])
# Sort by oldest to newest
bottom_media = bottom_media.sort_values(by="date")

# %%
bottom_media
# Out:
#                                                  text  \
# 0   When Japan's last oriental white stork died in...
# 0   Sign up to FREE email alerts from Mirror - dai...
# 0   World's worst endangered animal smuggling king...
# 0   By Richard Black\n\nEnvironment correspondent,...
# 0   By Matt Walker\n\nEditor, Earth News\n\n\n\nAn...
# ..                                                ...
# 0   Katharine Norbury\n\nTHE WASHINGTON POST – At ...
# 0   SHANGHAI — In early May, a fleet of yellow bul...
# 0   india\n\nUpdated: May 29, 2020 15:25 IST\n\nPe...
# 0   TAIPING: Taiping Zoo and Night Safari ((ZTNS) ...
# 0   Take a close look at these frogs. Even though ...
#
#                                                 title  \
# 0   Japan turns back clock to give new life to los...
# 0   The 12 days of Christmas (2009): Poet Laureate...
# 0   World's worst endangered animal smuggling kingpin
# 0       Giant salamander: Human threat, human promise
# 0   Bird conservation: Alaotra grebe confirmed ext...
# ..                                                ...
# 0   Ecologist turns human view of animal cultures ...
# 0        The Fierce Debate Over Shanghai’s New Forest
# 0   Amphan carries hundreds of oceanic birds into ...
# 0     ZTNS successfully breeds endangered milky stork
# 0                     Happy Amphibian Awareness Week!
#
#                                                  link  \
# 0   https://news.google.com/articles/CBMicGh0dHBzO...
# 0   https://news.google.com/articles/CBMiT2h0dHBzO...
# 0   https://news.google.com/articles/CBMiO2h0dHBzO...
# 0   https://news.google.com/articles/CBMiNWh0dHA6L...
# 0   https://news.google.com/articles/CBMiRGh0dHA6L...
# ..                                                ...
# 0   https://news.google.com/articles/CBMiYGh0dHBzO...
# 0   https://news.google.com/articles/CBMiUmh0dHBzO...
# 0   https://news.google.com/articles/CAIiEI94t2dnq...
# 0   https://news.google.com/articles/CBMiWWh0dHBzO...
# 0   https://news.google.com/articles/CBMiRmh0dHBzO...
#
#                                                 image       date  \
# 0   https://static.independent.co.uk/s3fs-public/t... 2008-05-24
# 0   https://i2-prod.mirror.co.uk/incoming/article4... 2009-12-07
# 0                       https://s0.wp.com/i/blank.jpg 2009-12-20
# 0                    http://www.bbc.co.uk/favicon.ico 2010-02-05
# 0                    http://www.bbc.co.uk/favicon.ico 2010-05-26
# ..                                                ...        ...
# 0   https://borneobulletin.com.bn/wp-content/uploa... 2020-05-25
# 0      http://image5.sixthtone.com/image/5/27/483.jpg 2020-05-28
# 0   https://www.hindustantimes.com/rf/image_size_9... 2020-05-29
# 0   https://www.theborneopost.com/newsimages/2020/... 2020-05-30
# 0   https://nationalzoo.si.edu/sites/default/files... 2020-06-01
#
#                                                   ner
# 0   {'sent': 'When Japan's last oriental white sto...
# 0   {'sent': 'Sign up to FREE email alerts from Mi...
# 0   {'sent': 'World's worst endangered animal smug...
# 0   {'sent': 'By Richard Black
#
# Environment corres...
# 0   {'sent': 'By Matt Walker
#
# Editor, Earth News
#
# ...
# ..                                                ...
# 0   {'sent': 'Katharine Norbury
#
# ', 'ents': {'PERS...
# 0   {'sent': 'SHANGHAI —', 'ents': {'ORG': ['SHANG...
# 0     {'sent': 'india
#
# ', 'ents': {'GPE': ['india']}}
# 0   {'sent': 'Taiping Zoo and Night Safari ((ZTNS)...
# 0   {'sent': 'Using DNA barcoding, Smithsonian Con...
#
# [226 rows x 6 columns]

# %%
import spacy 
nlp = spacy.load('en_core_web_sm')

# Create a new column named 'processed_txt'
bottom_media['processed_txt'] = None

# Apply the language model under 'nlp' to the contents of the DataFrame column 'text'
bottom_media['processed_txt'] = bottom_media['text'].apply(nlp)


# Define a function named 'get_ents' that takes a single object as input.
# We refer to this input using the variable name 'nlp_text'.
def get_ents(nlp_text):
    
    # First we make sure that the input is of correct type
    # by using the assert command to check the input type
    assert type(nlp_text) == spacy.tokens.doc.Doc
    
    # Let's set up a placeholder list for our ne's
    ents = []
    
    # We begin then begin looping over the Doc object
    for ent in nlp_text.ents:
        if (ent.label_ == 'GPE') | (ent.label_ == 'ORG') | (ent.label_ == 'LOC') | (ent.label_ == 'EVENT') | (ent.label_ == 'NORP'):
    
            # Append the ent text and label to the list of ents as a tuple
            ents.append(ent.text)
            
    # When the loop is complete, return the list of ents
    return ents

    
# Apply the 'get_ents' function to the column 'processed_txt'
bottom_media['ents'] = bottom_media['processed_txt'].apply(get_ents)

# Call the variable to examine the output
bottom_media
# Out:
#                                                  text  \
# 0   When Japan's last oriental white stork died in...
# 0   Sign up to FREE email alerts from Mirror - dai...
# 0   World's worst endangered animal smuggling king...
# 0   By Richard Black\n\nEnvironment correspondent,...
# 0   By Matt Walker\n\nEditor, Earth News\n\n\n\nAn...
# ..                                                ...
# 0   Katharine Norbury\n\nTHE WASHINGTON POST – At ...
# 0   SHANGHAI — In early May, a fleet of yellow bul...
# 0   india\n\nUpdated: May 29, 2020 15:25 IST\n\nPe...
# 0   TAIPING: Taiping Zoo and Night Safari ((ZTNS) ...
# 0   Take a close look at these frogs. Even though ...
#
#                                                 title  \
# 0   Japan turns back clock to give new life to los...
# 0   The 12 days of Christmas (2009): Poet Laureate...
# 0   World's worst endangered animal smuggling kingpin
# 0       Giant salamander: Human threat, human promise
# 0   Bird conservation: Alaotra grebe confirmed ext...
# ..                                                ...
# 0   Ecologist turns human view of animal cultures ...
# 0        The Fierce Debate Over Shanghai’s New Forest
# 0   Amphan carries hundreds of oceanic birds into ...
# 0     ZTNS successfully breeds endangered milky stork
# 0                     Happy Amphibian Awareness Week!
#
#                                                  link  \
# 0   https://news.google.com/articles/CBMicGh0dHBzO...
# 0   https://news.google.com/articles/CBMiT2h0dHBzO...
# 0   https://news.google.com/articles/CBMiO2h0dHBzO...
# 0   https://news.google.com/articles/CBMiNWh0dHA6L...
# 0   https://news.google.com/articles/CBMiRGh0dHA6L...
# ..                                                ...
# 0   https://news.google.com/articles/CBMiYGh0dHBzO...
# 0   https://news.google.com/articles/CBMiUmh0dHBzO...
# 0   https://news.google.com/articles/CAIiEI94t2dnq...
# 0   https://news.google.com/articles/CBMiWWh0dHBzO...
# 0   https://news.google.com/articles/CBMiRmh0dHBzO...
#
#                                                 image       date  \
# 0   https://static.independent.co.uk/s3fs-public/t... 2008-05-24
# 0   https://i2-prod.mirror.co.uk/incoming/article4... 2009-12-07
# 0                       https://s0.wp.com/i/blank.jpg 2009-12-20
# 0                    http://www.bbc.co.uk/favicon.ico 2010-02-05
# 0                    http://www.bbc.co.uk/favicon.ico 2010-05-26
# ..                                                ...        ...
# 0   https://borneobulletin.com.bn/wp-content/uploa... 2020-05-25
# 0      http://image5.sixthtone.com/image/5/27/483.jpg 2020-05-28
# 0   https://www.hindustantimes.com/rf/image_size_9... 2020-05-29
# 0   https://www.theborneopost.com/newsimages/2020/... 2020-05-30
# 0   https://nationalzoo.si.edu/sites/default/files... 2020-06-01
#
#                                                   ner  \
# 0   {'sent': 'When Japan's last oriental white sto...
# 0   {'sent': 'Sign up to FREE email alerts from Mi...
# 0   {'sent': 'World's worst endangered animal smug...
# 0   {'sent': 'By Richard Black
#
# Environment corres...
# 0   {'sent': 'By Matt Walker
#
# Editor, Earth News
#
# ...
# ..                                                ...
# 0   {'sent': 'Katharine Norbury
#
# ', 'ents': {'PERS...
# 0   {'sent': 'SHANGHAI —', 'ents': {'ORG': ['SHANG...
# 0     {'sent': 'india
#
# ', 'ents': {'GPE': ['india']}}
# 0   {'sent': 'Taiping Zoo and Night Safari ((ZTNS)...
# 0   {'sent': 'Using DNA barcoding, Smithsonian Con...
#
#                                         processed_txt  \
# 0   (When, Japan, 's, last, oriental, white, stork...
# 0   (Sign, up, to, FREE, email, alerts, from, Mirr...
# 0   (World, 's, worst, endangered, animal, smuggli...
# 0   (By, Richard, Black, \n\n, Environment, corres...
# 0   (By, Matt, Walker, \n\n, Editor, ,, Earth, New...
# ..                                                ...
# 0   (Katharine, Norbury, \n\n, THE, WASHINGTON, PO...
# 0   (SHANGHAI, —, In, early, May, ,, a, fleet, of,...
# 0   (india, \n\n, Updated, :, May, 29, ,, 2020, 15...
# 0   (TAIPING, :, Taiping, Zoo, and, Night, Safari,...
# 0   (Take, a, close, look, at, these, frogs, ., Ev...
#
#                                                 ner_2  \
# 0   [{Japan, GPE}, {DATE, 1971}, {more than three ...
# 0   [{FREE, ORG}, {Mirror - daily, ORG}, {Subscrib...
# 0   [{PERSON, Marilyn}, {PERSON, Bryan Christy}, {...
# 0   [{Richard Black\n\nEnvironment, PERSON}, {ORG,...
# 0   [{PERSON, Matt Walker}, {Earth News, ORG}, {Al...
# ..                                                ...
# 0   [{Katharine Norbury, ORG}, {THE WASHINGTON POS...
# 0   [{DATE, early May}, {Hangzhou Bay, LOC}, {PERS...
# 0   [{india, GPE}, {May 29, 2020 15:25, DATE}, {CA...
# 0   [{Taiping Zoo, ORG}, {PERSON, Night Safari}, {...
# 0   [{Smithsonian Conservation Biology Institute, ...
#
#                                                  ents
# 0   [Japan, Toyooka, Independent Premium, Japan, H...
# 0   [FREE, Mirror - daily, Subscribe, Invalid, the...
# 0   [National Geographic, the US Fish & Wildlife S...
# 0   [BBC News\n\nPlease, JavaScript, JavaScript, T...
# 0   [Earth News, Alaotra, Alaotra, Lake Alaotra, C...
# ..                                                ...
# 0   [Katharine Norbury, THE WASHINGTON POST, the N...
# 0   [Hangzhou Bay, Shanghai, Shanghai, East Asian-...
# 0   [india, West Bengal, Sunderbans, India, ZSI, K...
# 0   [Taiping Zoo, Taiping Municipal Council, Zubir...
# 0   [Smithsonian Conservation Biology Institute, t...
#
# [226 rows x 9 columns]

# %%
bottom_media.to_csv("bottom_20_articles.csv")

# %%
# Cast pandas Series to a list
ner_list = bottom_media['ents'].tolist()

# Set up the placeholder list
final_list = []

# Loop over each list in the list of lists
for nlist in ner_list:
    
    # Extend the final list with the current list
    final_list.extend(nlist)
    
# Convert the list into a pandas Series, count unique nouns
# using the value_counts() method, get the 10 most frequent
# items [:10] and plot the result into a bar chart using the
# plot() method and its attribute 'kind'.
pd.Series(final_list).value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# create a dataframe of the articles found under each species instance 
# How to bring over the species names that have been "identified" for each article? **

top_media = pd.DataFrame()

for i in top_twen.articles:
    for x in i.values():
        nd = pd.DataFrame.from_dict(x)
        top_media = pd.concat([top_media, nd])
        
        
# keep only unique article instances
top_media = top_media.drop_duplicates(subset=['text'])


## lets run a quick keyword search
# 71 articles identified out of 1887. That is 3% of the dataset for Top 20 species
# Manual classification to asses what species are mentioned, geographic locations, reporting agency, information provided, accuracy and relevancy of information in conservation research of the species 
illegaltrade_top20_articles = top20[top20['text'].str.contains('seiz|confiscat')]
#top_media[top_media['text'].str.contains('seiz|confiscat|trade|poach')]
# Save articles dataframe
illegaltrade_top20_articles.to_csv("illegaltrade_top20_articles.csv")
# Out:
#                                                  text  \
# 0   Advertisement\n\nFrom the tropics of the south...
# 0   GPS-locations help first time visitors to reac...
# 0   “Dilli ke Patrakar" (journalist from Delhi). I...
# 0   One of the prettiest hill stations of Himachal...
# 0   There are 400 species of mammals in India. Clo...
# ..                                                ...
# 0   Hey, all you cool cats and kittens! (Sorry.) N...
# 0   Sign up to FREE email alerts from Nottinghamsh...
# 0   A rediscovered black-and-white video clip is t...
# 0   india\n\nUpdated: May 27, 2020 18:56 IST\n\nAr...
# 0   Wild animals don’t want to be in your selfies....
#
#                                                 title  \
# 0   Wild India by Axel Gomille is a real-life Jung...
# 0                         Trek made easy for tourists
# 0            Kuno Wildlife Sanctuary: Ready for lions
# 0   Why Visit Chail – Home to The Highest Cricket ...
# 0                        Book Review | Indian Mammals
# ..                                                ...
# 0   “I Saw a Tiger, and the Tiger Saw Man”: 8 Book...
# 0   Grave of Notts man 'mauled' by tiger in 1915 u...
# 0   Last-known video of 'Tasmanian tiger' rediscov...
# 0   Cyclone Amphan destroys one-third of world’s l...
# 0      Take a Safe Tiger Selfie From Home? Here's How
#
#                                                  link  \
# 0   https://news.google.com/articles/CBMicWh0dHBzO...
# 0   https://news.google.com/articles/CBMiSGh0dHBzO...
# 0   https://news.google.com/articles/CBMiZWh0dHBzO...
# 0   https://news.google.com/articles/CBMibmh0dHBzO...
# 0   https://news.google.com/articles/CBMiWGh0dHBzO...
# ..                                                ...
# 0   https://news.google.com/articles/CBMiNWh0dHA6L...
# 0   https://news.google.com/articles/CBMiU2h0dHBzO...
# 0   https://news.google.com/articles/CBMiRWh0dHBzO...
# 0   https://news.google.com/articles/CAIiEAyBmUkVJ...
# 0   https://news.google.com/articles/CBMiP2h0dHBzO...
#
#                                                 image        date  \
# 0   https://i.dailymail.co.uk/i/pix/2017/11/23/08/...  11/23/2017
# 0   https://www.deccanherald.com/sites/dh/files/ar...  05/23/2015
# 0   https://www.livemint.com/rf/Image-621x414/Live...  04/22/2013
# 0   https://s3.india.com/wp-content/uploads/2015/0...  05/16/2019
# 0   https://images.livemint.com/rf/Image-621x414/L...  06/28/2014
# ..                                                ...         ...
# 0   https://s2982.pcdn.co/wp-content/uploads/2020/...  05/22/2020
# 0   https://i2-prod.nottinghampost.com/incoming/ar...  05/30/2020
# 0   https://cdn.mos.cms.futurecdn.net/tXCaynsprefT...  05/29/2020
# 0   https://www.hindustantimes.com/rf/image_size_9...  05/27/2020
# 0   https://www.peta.org/wp-content/uploads/2020/0...  05/20/2020
#
#                                                   ner
# 0   {'sent': 'Photographer Axel Gomille spent 25 y...
# 0   {'sent': 'GPS-locations help first time visito...
# 0   {'sent': '“Dilli ke Patrakar" (journalist from...
# 0   {'sent': 'One of the prettiest hill stations o...
# 0   {'sent': 'There are 400 species of mammals in ...
# ..                                                ...
# 0   {'sent': 'Now that we’re all still indoors and...
# 0   {'sent': 'Sign up to FREE email alerts from No...
# 0   {'sent': 'The 21-second clip shows a thylacine...
# 0     {'sent': 'india
#
# ', 'ents': {'GPE': ['india']}}
# 0   {'sent': '(AR) technology from', 'ents': {'ORG...
#
# [1887 rows x 6 columns]

# %%
# Whole dataset articles
read = pd.DataFrame()

for i in df.articles:
    for x in i.values():
        nd = pd.DataFrame.from_dict(x)
        read = pd.concat([read, nd])

# keep only unique article instances
read = read.drop_duplicates(subset=['text'])

# Transform date column into DateTime
read["date"] = pd.to_datetime(read["date"])
# Sort by oldest to newest
read = read.sort_values(by="date")

read.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [78], line 7
#       5     for x in i.values():
#       6         nd = pd.DataFrame.from_dict(x)
# ----> 7         read = pd.concat([read, nd])
#       9 # keep only unique article instances
#      10 read = read.drop_duplicates(subset=['text'])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/concat.py:616, in _Concatenator.get_result(self)
#     612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
# --> 616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#     619 if not self.copy:
#     620     new_data._consolidate_inplace()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/concat.py:223, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     217 vals = [ju.block.values for ju in join_units]
#     219 if not blk.is_extension:
#     220     # _is_uniform_join_units ensures a single dtype, so
#     221     #  we can use np.concatenate, which is more performant
#     222     #  than concat_compat
# --> 223     values = np.concatenate(vals, axis=1)
#     224 else:
#     225     # TODO(EA2D): special-casing not needed with 2D EAs
#     226     values = concat_compat(vals, axis=1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# Create a quick visualization of the date distribution 
read.groupby(read["date"].dt.year).count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Read in the CITES data to join with the top 10 (or 20) most reported on species 
cites1 = pd.read_csv("cites1.csv")

# Keep only most relevant columns
cites1 = cites1[['Kingdom', 'Class', 'Family', 'Genus', 'Species', 'FullName', 'NativeDistributionFullNames']]

cites1 = cites1.rename(columns = {'FullName' : 'scientific_name'})

cites1
# Out:
#        Kingdom     Class     Family        Genus      Species  \
# 0     Animalia  Reptilia   Anguidae      Abronia     anzuetoi
# 1     Animalia  Reptilia   Anguidae      Abronia    campbelli
# 2     Animalia  Reptilia   Anguidae      Abronia    fimbriata
# 3     Animalia  Reptilia   Anguidae      Abronia       frosti
# 4     Animalia  Reptilia   Anguidae      Abronia     meledona
# ...        ...       ...        ...          ...          ...
# 1206   Plantae       NaN  Cactaceae  Uebelmannia          NaN
# 1207   Plantae       NaN  Cactaceae  Uebelmannia    buiningii
# 1208   Plantae       NaN  Cactaceae  Uebelmannia    gummifera
# 1209   Plantae       NaN  Cactaceae  Uebelmannia  pectinifera
# 1210   Plantae       NaN  Zamiaceae        Zamia    restrepoi
#
#               scientific_name NativeDistributionFullNames
# 0            Abronia anzuetoi                   Guatemala
# 1           Abronia campbelli                   Guatemala
# 2           Abronia fimbriata                   Guatemala
# 3              Abronia frosti                   Guatemala
# 4            Abronia meledona                   Guatemala
# ...                       ...                         ...
# 1206              Uebelmannia                         NaN
# 1207    Uebelmannia buiningii                      Brazil
# 1208    Uebelmannia gummifera                      Brazil
# 1209  Uebelmannia pectinifera                      Brazil
# 1210          Zamia restrepoi                    Colombia
#
# [1211 rows x 7 columns]

# %%
# Simplify the IUCN categories

df["iucn_status"].replace({"Least Concern": "LC", "Lower Risk/least concern": "LC", 
                                "Vulnerable" : "VU", "Near Threatened" : "NT", "Critically Endangered" : "CR",
                          "Extinct in the Wild" : "EW", "Endangered" : "EN", "Data Deficient" : "DD", 
                          "Extinct" : "EX"}, inplace=True)

df['iucn_status'].unique()

## DROP NA
df_mod = df[ (df['iucn_status'] != 'NA') & (df['iucn_status'] != ' Brede & Rödel')]
df_mod
#df.drop(df.loc[df['iucn_status'].isin(['NA'])])
#df.loc[df['scientific_name'].isin(['Perameles bougainville'])]
# Out:
# /tmp/ipykernel_93/1468945897.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["iucn_status"].replace({"Least Concern": "LC", "Lower Risk/least concern": "LC",
# array(['CR', 'LC', 'NT', 'NA', 'EW', 'VU', 'EN', 'DD', 'EX',
#        'Lower Risk/conservation dependent', ' Brede & Rödel'],
#       dtype=object)

# %%
# Assigning each category a more relevant color
cmap = {'CR': 'red', 'EN': 'orange', 'VU': 'yellow', 'NT': 'green', 'LC': 'blue'}

# %%
colors = ['#2059BA','#FAE666','#A90A0A','#F9820B', '#128A16']

# %%
# Group dataframe by the scientific name that remains consistent for all rows 
grouped_i = df_mod.groupby('iucn_status')

# Calculate the totals of the group species
article_totals_i = grouped_i.article_amt.sum().round()


# What species are being reported on the most? 
# Create a simple bar graph displaying the amt of articles per species 
ax = article_totals_i.plot.bar(cmap, figsize = (7,7), 
                                                fontsize = 12)
ax.set_ylabel('Article Amount', fontsize=16)
ax.set_title('IUCN Status Share of Dataset', fontsize = 20)
#plt.savefig('IUCN-share.png', bbox_inches = 'tight')
# Out:
# Text(0.5, 1.0, 'IUCN Status Share of Dataset')

# %%
# Defining parameters for pie chart of IUCN Status
ax = top_twen['iucn_status'].value_counts().plot(kind = 'pie', autopct="%1.1f%%", figsize = (7,7), 
                                                fontsize = 12, colors = colors)

ax.set_ylabel('IUCN Status', fontsize=16)
ax.set_title('IUCN Status Distribution of Top 20 Most Reported on Species', fontsize = 20)
plt.savefig('IUCN-status.png', bbox_inches = 'tight')

# %%
# A quick look at the species' distribution
g = top_twen['article_amt'].groupby(top_twen['scientific_name'])

# %%
# Create a simplified version of the dataframe
smplfd = top_twen[['scientific_name', 'distribution', 'iucn_status']]
smplfd.drop_duplicates(inplace = True)
smplfd.reset_index(drop = True, inplace = True)
# Conduct merges of the dataframes
smplfd.merge(cites1, on = 'scientific_name', how = 'inner')
smplfd

# %%
# Do the same for the entire dataframe
df = df.merge(cites1, on = 'scientific_name', how = 'inner')

# %%
# Group dataframe by the Kingdom that remains consistent for all rows 
grouped_k = df.groupby('Kingdom')

# Calculate the totals of the group Kingdom
article_totals_k = grouped_k.article_amt.sum().round()

# %%
article_totals_k
# Out:
# Kingdom
# Animalia    13390.0
# Plantae       175.0
# Name: article_amt, dtype: float64

# %%
# What Kingdom is being reported on the most? 
# Create a simple pie chart displaying the amt of articles per Kingdom
ax = article_totals_k.plot.pie(y = 'Kingdom', autopct="%1.1f%%", figsize = (7,7), fontsize = 12)
ax.set_ylabel('Articles', labelpad = 35, fontsize=16)
ax.set_title('Kingdom Share ', fontsize = 20)
plt.savefig('Kingdom-Share.png', bbox_inches = 'tight')

# %%
df['Class'].value_counts()
# Out:
# Mammalia          1220
# Aves               498
# Reptilia           338
# Actinopteri         46
# Amphibia            30
# Elasmobranchii      24
# Bivalvia            24
# Coelacanthi          9
# Insecta              8
# Name: Class, dtype: int64

# %%
# Group dataframe by the Class that remains consistent for all rows 
grouped_c = df.groupby('Class')

# Calculate the totals of the Classes
article_totals_c = grouped_c.article_amt.sum().round()


# What Class is being reported on the most? 
# Create a simple pie graph displaying the amt of articles per species 
ax = article_totals_c.plot.bar(figsize = (20,20), autopct="%1.1f%%", fontsize = 12, rotatelabels=True)

ax.set_ylabel('Article Amount', labelpad = 35, fontsize=20)
ax.set_title('Class Share in Dataset', pad = 35, fontsize = 30)
plt.savefig('class-share.png', bbox_inches = 'tight')

# %%
# Group dataframe by the scientific name that remains consistent for all rows 
grouped_G = df.groupby('Genus')

# Calculate the totals of the group species
article_totals_G = grouped_G.article_amt.sum().round()


# What species are being reported on the most? 
# Create a simple bar graph displaying the amt of articles per species 
ax = article_totals_G.nlargest(20).plot.bar(color = 'blue', figsize = (10,7), fontsize = 12)
ax.set_xlabel('Genus', fontsize=16)
ax.set_ylabel('Article Amount', fontsize = 16)
ax.set_title('Genus by Article Amount (Top 20)', fontsize = 20)
ax.tick_params(axis='x', rotation=80, left = True, pad = 2)
plt.savefig('top_20_genus.png', bbox_inches = 'tight')

# %% [markdown]
# 13/04/22
#
# Next visualization step:
# - Don't just visualize the dataset, look at the corresponding articles published for that class! for that genus! SO need to do groupby functions
