# %%
import pandas as pd
import geopandas as gpd
import json
from ast import literal_eval
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in the dataset 
df = pd.read_json('animal_news_database.json', lines = True)
df
# Out:
#                                        _id                   common_name  \
# 0     {'$oid': '5eb530eeccc46a6a739577a2'}   Campbell's alligator lizard
# 1     {'$oid': '5eb53116ccc46a6a739577a6'}   Southern plains gray langur
# 2     {'$oid': '5eb53156ccc46a6a739577ab'}             Natal giant cycad
# 3     {'$oid': '5eb53162ccc46a6a739577ad'}         Bengal hanuman langur
# 4     {'$oid': '5eb53171ccc46a6a739577af'}            Mongolian Wild Ass
# ...                                    ...                           ...
# 2272  {'$oid': '5ed349928089be8ca72beb86'}                    Chimpanzee
# 2273  {'$oid': '5ed34a668089be8ca72beb87'}             Common chimpanzee
# 2274  {'$oid': '5ed352f08089be8ca72beb8a'}              @TRAFFIC_WLTrade
# 2275  {'$oid': '5ed355ec8089be8ca72beb8b'}                  @IlWildTrade
# 2276  {'$oid': '5ed35b528089be8ca72beb8c'}                  @WLTradeNews
#
#                scientific_name  \
# 0            Abronia campbelli
# 1     Semnopithecus dussumieri
# 2     Encephalartos natalensis
# 3       Semnopithecus entellus
# 4      Equus hemionus hemionus
# ...                        ...
# 2272           Pan troglodytes
# 2273           Pan troglodytes
# 2274          @TRAFFIC_WLTrade
# 2275              @IlWildTrade
# 2276              @WLTradeNews
#
#                                            distribution  \
# 0                                             Guatemala
# 1                                                 India
# 2                                          South Africa
# 3                    Bangladesh, India, Nepal, Pakistan
# 4       China, Kazakhstan, Mongolia, Russian Federation
# ...                                                 ...
# 2272  Angola, Benin, Burkina Faso, Burundi, Cameroon...
# 2273  Angola, Benin, Burkina Faso, Burundi, Cameroon...
# 2274                                                 NA
# 2275                                                 NA
# 2276                                                 NA
#
#                 iucn_status  \
# 0     Critically Endangered
# 1             Least Concern
# 2           Near Threatened
# 3             Least Concern
# 4                        NA
# ...                     ...
# 2272                     EN
# 2273                     EN
# 2274                     NA
# 2275                     NA
# 2276                     NA
#
#                                                articles  date_saved
# 0     {'0': {'text': 'A 3-foot-long (1 meter) green ...  2020-06-18
# 1     {'3': {'text': 'On Thursday, a Nilgai was foun...  2020-06-18
# 2     {'0': {'text': 'A GUIDED walk entitled Interes...  2020-06-18
# 3     {'1': {'text': 'Advertisement
#
# From the tropic...  2020-06-18
# 4     {'0': {'text': 'Exploding demand for cashmere ...  2020-06-18
# ...                                                 ...         ...
# 2272  {'0': {'text': 'The Chimpanzee Sanctuary & Wil...  2020-06-18
# 2273                                                 {}  2020-06-18
# 2274  {'0': {'text': 'Pangolins are trafficked for t...  2020-06-18
# 2275  {'0': {'text': 'india
#
# Updated: May 03, 2016 1...  2020-06-18
# 2276  {'0': {'text': 'This evening, Prince William a...  2020-06-18
#
# [2277 rows x 7 columns]

# %%
# Drop Twitter handles as they are not species names
df = df[df.scientific_name.str.contains('@') == False]
df.reset_index(drop = True, inplace = True)

# %%
# Add new column for storing the values article amount found under each species type 

for i, row in df.iterrows():
    df.at[i, 'article_amt'] = len(row.articles.values())
# Out:
# /tmp/ipykernel_131/2111529173.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.at[i, 'article_amt'] = len(row.articles.values())

# %%
# Two lists that contain the 5 charismatic species and 5 EDGE species
charismatic = ["Panthera tigris", "Loxodonta africana", "Ailuropoda melanoleuca", "Gavialis gangeticus", "Platanista gangetica"]
edge = ["Andrias davidianus", "Shinisaurus crocodilurus", "Houbaropsis bengalensis", "Manis pentadactyla", "Tapirus baridii"]

# %%
def list_to_df(lst, df):
    ''''''
    ## Create dfs out of list 
    ''''''
    # creating a blank pandas df
    blank = pd.DataFrame()
    for spec in lst:
        new = df.loc[df['scientific_name'].isin([spec])]
        blank = blank.append(new)
        
    
    # Group dataframe by the scientific name that remains consistent for all rows 
    grouped = blank.groupby('scientific_name')

    # Calculate the totals of the group species
    article_totals = grouped.article_amt.sum().round()
    
    # create a dataframe of the articles found under each species instance 
    # How to bring over the species names that have been "identified" for each article? **

    media = pd.DataFrame()

    for i in blank.articles:
        for x in i.values():
            nd = pd.DataFrame.from_dict(x)
            media = media.append(nd)
        
        
    # keep only unique article instances
    media = media.drop_duplicates(subset=['text'])
    
    return media

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
media = list_to_df(edge, df)

# %%
def categorise(row):  
    if 'pangolin' in row["text"]:
        return 'Pangolin'
    elif 'salamander' in row["text"]:
        return 'Chinese Giant Salamander'
    elif 'florican' in row["text"]:
        return 'Bengal Florican'
    return 'Chinese Crocodile Lizard'


media['species'] = media.apply(lambda row: categorise(row), axis=1)

# %%
# Transform date column into DateTime
media["date"] = pd.to_datetime(media["date"])
# Sort by oldest to newest
media = media.sort_values(by="date")

media.head()
# Out:
#                                                 text  \
# 0  By Richard Black\n\nEnvironment Correspondent,...
# 0  Steven Brooks grew up in the Hudson Valley of ...
# 0  Houston Zoo takes action when animals get stre...
# 0  Kolkata : Fifteen Indian bird species are part...
# 0  Entire branches of the tree of life are in dan...
#
#                                                title  \
# 0                   Hunting threat to big amphibians
# 0  New Yorker looks to buy a lizard, gets whole f...
# 0  Houston Zoo takes action when animals get stre...
# 0  15 Indian bird species among globally endanger...
# 0  Threatened Species 'Red List' Warns 90 Percent...
#
#                                                 link  \
# 0  https://news.google.com/articles/CBMiNWh0dHA6L...
# 0  https://news.google.com/articles/CBMiR2h0dHBzO...
# 0  https://news.google.com/articles/CBMib2h0dHBzO...
# 0  https://news.google.com/articles/CBMic2h0dHBzO...
# 0  https://news.google.com/articles/CBMieGh0dHBzO...
#
#                                                image       date  \
# 0  http://newsimg.bbc.co.uk/media/images/40816000... 2005-09-19
# 0  https://www.al.com/resizer/VXCMJHahaq-eEg50p6m... 2010-09-07
# 0  https://s.hdnux.com/photos/04/50/61/1215605/3/... 2011-08-01
# 0  https://images.livemint.com/rf/Image-621x414/L... 2014-04-19
# 0  https://www.nationalgeographic.com/content/dam... 2014-06-13
#
#                                                  ner                   species
# 0  {'sent': 'By Richard Black
#
# Environment Corres...  Chinese Giant Salamander
# 0  {'sent': 'Steven Brooks grew up in the Hudson ...  Chinese Crocodile Lizard
# 0  {'sent': 'Houston Zoo takes action when animal...  Chinese Crocodile Lizard
# 0  {'sent': 'Kolkata :', 'ents': {'PERSON': ['Kol...  Chinese Crocodile Lizard
# 0  {'sent': 'The list, which is managed by the In...  Chinese Crocodile Lizard

# %%
# Save articles dataframe
media.to_csv("5edge_articles.csv")

# %%
cmedia = list_to_df(charismatic, df)

# %%
# Re-assign labels for the dataframe that better communicates what species are mentioned
def categorise(row):  
    if 'tiger' in row["text"]:
        return 'Tiger'
    elif 'elephant' in row["text"]:
        return 'Elephant'
    elif 'panda' in row["text"]:
        return 'Giant White Panda'
    elif 'gharial' in row["text"]:
        return 'Gharial'
    return 'Indus River Dolphin'


cmedia['species'] = cmedia.apply(lambda row: categorise(row), axis=1)

# Transform date column into DateTime
cmedia["date"] = pd.to_datetime(cmedia["date"])
# Sort by oldest to newest
cmedia = cmedia.sort_values(by="date")

cmedia.head()
# Out:
#                                                 text  \
# 0  A Gharial crocodile rests besides a pond at hi...
# 0  What is the African elephant?\n\nAfrican eleph...
# 0  NARORA, India (Reuters Life!) - As the sun set...
# 0  The African elephant is actually two different...
# 0  This bizarre crocodilian from northern India, ...
#
#                                                title  \
# 0        Indian crocodiles "video blog" for survival
# 0                                   African elephant
# 0  Conservation and religion join to save Ganges ...
# 0  African Elephants Really Two Wildly Different ...
# 0  Where the weird things are: The gharial - a cr...
#
#                                                 link  \
# 0  https://news.google.com/articles/CBMicWh0dHBzO...
# 0  https://news.google.com/articles/CBMiRmh0dHBzO...
# 0  https://news.google.com/articles/CBMifWh0dHBzO...
# 0  https://news.google.com/articles/CBMiYWh0dHBzO...
# 0  https://news.google.com/articles/CBMieGh0dHBzO...
#
#                                                image       date  \
# 0  https://s1.reutersmedia.net/resources/r/?m=02&... 2009-11-09
# 0  https://www.nationalgeographic.com/content/dam... 2010-09-10
# 0  https://s4.reutersmedia.net/resources_v2/image... 2010-10-28
# 0  https://www.nationalgeographic.com/content/dam... 2010-12-22
# 0  https://news.google.com/img/shortcut-icons/fav... 2011-01-29
#
#                                                  ner              species
# 0  {'sent': 'A Gharial crocodile rests besides a ...              Gharial
# 0  {'sent': 'Currently, most still consider them ...             Elephant
# 0  {'sent': 'NARORA, India (', 'ents': {'ORG': ['...  Indus River Dolphin
# 0  {'sent': 'The African elephant is actually two...             Elephant
# 0  {'sent': 'This bizarre crocodilian from northe...              Gharial

# %%
cmedia.to_csv("5charismatic_articles.csv")
